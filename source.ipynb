# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
pd.set_option('display.max_columns', 1000)

train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
import nltk
import re
from string import punctuation

# %%
tokenizer = nltk.tokenize.TreebankWordTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()
stemmer = nltk.stem.PorterStemmer()
train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
train['text'] = train['text'].apply(lambda x: re.sub(r'@[a-zA-Z_]+', '', x))
train['text'] = train['text'].apply(lambda x: re.sub('#', '', x))
train['text'] = train['text'].apply(lambda x: x.lower())
train['text'] = train['text'].apply(lambda x: re.sub(r'\d+', '', x))
train['text'] = train['text'].apply(lambda x: re.sub('http', '', x))
train['text'] = train['text'].apply(lambda x: re.sub('//t.co/.*', '', x))
train['text'] = train['text'].apply(lambda x: re.sub('/+', '', x))
train['text'] = train['text'].apply(lambda x: re.sub('[;.,–-]', '', x))
train['text'] = train['text'].apply(lambda x: re.sub('[.+]', '', x))
train['text'] = train['text'].apply(lambda x: re.sub(chr(0x89) + '.*', '', x))
train['text'] = train['text'].apply(lambda x: re.sub(r'\*+', '', x))
train['text'] = train['text'].apply(lambda x: re.sub(r'\|+', '', x))
train['text'] = train['text'].apply(lambda x: re.sub(r'_', '', x))
train['text'] = train['text'].apply(lambda x: re.sub(r'å¤', '', x))
train['text'] = train['text'].apply(lambda x: re.sub(r'ìü', '', x))

# %%
cleared_train = train['text'].copy()
cleared_train
# Out:
# 0       our deeds are the reason of this earthquake ma...
# 1                   forest fire near la ronge sask canada
# 2       all residents asked to 'shelter in place' are ...
# 3        people receive wildfires evacuation orders in...
# 4       just got sent this photo from ruby alaska as s...
#                               ...
# 7608    two giant cranes holding a bridge collapse int...
# 7609      the out of control wild fires in california ...
# 7610                   m [: utc]?km s of volcano hawaii :
# 7611    police investigating after an ebike collided w...
# 7612    the latest: more homes razed by northern calif...
# Name: text, Length: 7613, dtype: object

# %%
o_toknized_train = pd.Series([tokenizer.tokenize(sent) for sent in cleared_train])

toknized_train = []

for item in o_toknized_train:
    temp = []
    for word in item:
        temp.append(stemmer.stem(word))
        
    toknized_train.append(temp)

toknized_train
# Out:
# [['our',
#   'deed',
#   'are',
#   'the',
#   'reason',
#   'of',
#   'thi',
#   'earthquak',
#   'may',
#   'allah',
#   'forgiv',
#   'us',
#   'all'],
#  ['forest', 'fire', 'near', 'la', 'rong', 'sask', 'canada'],
#  ['all',
#   'resid',
#   'ask',
#   'to',
#   "'shelter",
#   'in',
#   'place',
#   "'",
#   'are',
#   'be',
#   'notifi',
#   'by',
#   'offic',
#   'no',
#   'other',
#   'evacu',
#   'or',
#   'shelter',
#   'in',
#   'place',
#   'order',
#   'are',
#   'expect'],
#  ['peopl', 'receiv', 'wildfir', 'evacu', 'order', 'in', 'california'],
#  ['just',
#   'got',
#   'sent',
#   'thi',
#   'photo',
#   'from',
#   'rubi',
#   'alaska',
#   'as',
#   'smoke',
#   'from',
#   'wildfir',
#   'pour',
#   'into',
#   'a',
#   'school'],
#  ['rockyfir',
#   'updat',
#   '=',
#   '>',
#   'california',
#   'hwi',
#   'close',
#   'in',
#   'both',
#   'direct',
#   'due',
#   'to',
#   'lake',
#   'counti',
#   'fire',
#   'cafir',
#   'wildfir'],
#  ['flood',
#   'disast',
#   'heavi',
#   'rain',
#   'caus',
#   'flash',
#   'flood',
#   'of',
#   'street',
#   'in',
#   'manit',
#   'colorado',
#   'spring',
#   'area'],
#  ['i',
#   "'m",
#   'on',
#   'top',
#   'of',
#   'the',
#   'hill',
#   'and',
#   'i',
#   'can',
#   'see',
#   'a',
#   'fire',
#   'in',
#   'the',
#   'wood'],
#  ['there',
#   "'s",
#   'an',
#   'emerg',
#   'evacu',
#   'happen',
#   'now',
#   'in',
#   'the',
#   'build',
#   'across',
#   'the',
#   'street'],
#  ['i',
#   "'m",
#   'afraid',
#   'that',
#   'the',
#   'tornado',
#   'is',
#   'come',
#   'to',
#   'our',
#   'area'],
#  ['three', 'peopl', 'die', 'from', 'the', 'heat', 'wave', 'so', 'far'],
#  ['haha',
#   'south',
#   'tampa',
#   'is',
#   'get',
#   'flood',
#   'hah',
#   'wait',
#   'a',
#   'second',
#   'i',
#   'live',
#   'in',
#   'south',
#   'tampa',
#   'what',
#   'am',
#   'i',
#   'gon',
#   'na',
#   'do',
#   'what',
#   'am',
#   'i',
#   'gon',
#   'na',
#   'do',
#   'fvck',
#   'flood'],
#  ['rain',
#   'flood',
#   'florida',
#   'tampabay',
#   'tampa',
#   'or',
#   'day',
#   'i',
#   "'ve",
#   'lost',
#   'count'],
#  ['flood', 'in', 'bago', 'myanmar', 'we', 'arriv', 'bago'],
#  ['damag', 'to', 'school', 'bu', 'on', 'in', 'multi', 'car', 'crash', 'break'],
#  ['what', "'s", 'up', 'man', '?'],
#  ['i', 'love', 'fruit'],
#  ['summer', 'is', 'love'],
#  ['my', 'car', 'is', 'so', 'fast'],
#  ['what', 'a', 'goooooooaaaaaal', '!', '!', '!', '!', '!', '!'],
#  ['thi', 'is', 'ridicul'],
#  ['london', 'is', 'cool', ')'],
#  ['love', 'ski'],
#  ['what', 'a', 'wonder', 'day', '!'],
#  ['looooool'],
#  ['no', 'wayi', 'ca', "n't", 'eat', 'that', 'shit'],
#  ['wa', 'in', 'nyc', 'last', 'week', '!'],
#  ['love', 'my', 'girlfriend'],
#  ['cooool', ':', ')'],
#  ['do', 'you', 'like', 'pasta', '?'],
#  ['the', 'end', '!'],
#  ['wholesal', 'market', 'ablaz', ':'],
#  ['we', 'alway', 'tri', 'to', 'bring', 'the', 'heavi', 'metal', 'rt', ':'],
#  ['africanbaz',
#   ':',
#   'break',
#   'news',
#   ':',
#   'nigeria',
#   'flag',
#   'set',
#   'ablaz',
#   'in',
#   'aba',
#   ':'],
#  ['cri', 'out', 'for', 'more', '!', 'set', 'me', 'ablaz'],
#  ['on',
#   'plu',
#   'side',
#   'look',
#   'at',
#   'the',
#   'sky',
#   'last',
#   'night',
#   'it',
#   'wa',
#   'ablaz',
#   ':'],
#  ['mufc',
#   'they',
#   "'ve",
#   'built',
#   'so',
#   'much',
#   'hype',
#   'around',
#   'new',
#   'acquisit',
#   'but',
#   'i',
#   'doubt',
#   'they',
#   'will',
#   'set',
#   'the',
#   'epl',
#   'ablaz',
#   'thi',
#   'season'],
#  ['inec', 'offic', 'in', 'abia', 'set', 'ablaz', ':'],
#  ['barbado', 'bridgetown', 'jamaica'],
#  ['ablaz', 'for', 'you', 'lord', ':', 'd'],
#  ['check', 'these', 'out', ':', ':'],
#  ['on',
#   'the',
#   'outsid',
#   'you',
#   "'re",
#   'ablaz',
#   'and',
#   'aliv',
#   'but',
#   'you',
#   "'re",
#   'dead',
#   'insid'],
#  ['had',
#   'an',
#   'awesom',
#   'time',
#   'visit',
#   'the',
#   'cfc',
#   'head',
#   'offic',
#   'the',
#   'ancop',
#   'site',
#   'and',
#   'ablaz',
#   'thank',
#   'to',
#   'tita',
#   'vida',
#   'for',
#   'take',
#   'care',
#   'of',
#   'us',
#   '?',
#   '?'],
#  ['soooo', 'pump', 'for', 'ablaz', '?', '?', '?', '?'],
#  ['i',
#   'want',
#   'to',
#   'set',
#   'chicago',
#   'ablaz',
#   'with',
#   'my',
#   'preach',
#   'but',
#   'not',
#   'my',
#   'hotel',
#   '!',
#   ':'],
#  ['i',
#   'gain',
#   'follow',
#   'in',
#   'the',
#   'last',
#   'week',
#   'you',
#   '?',
#   'know',
#   'your',
#   'stat',
#   'and',
#   'grow',
#   'with',
#   ':'],
#  ['how',
#   'the',
#   'west',
#   'wa',
#   'burn',
#   ':',
#   'thousand',
#   'of',
#   'wildfir',
#   'ablaz',
#   'in',
#   'california',
#   'alon',
#   ':'],
#  ['build',
#   'the',
#   'perfect',
#   'tracklist',
#   'to',
#   'life',
#   'leav',
#   'the',
#   'street',
#   'ablaz'],
#  ['check', 'these', 'out', ':', ':'],
#  ['first',
#   'night',
#   'with',
#   'retain',
#   'in',
#   'it',
#   "'s",
#   'quit',
#   'weird',
#   'better',
#   'get',
#   'use',
#   'to',
#   'it',
#   'i',
#   'have',
#   'to',
#   'wear',
#   'them',
#   'everi',
#   'singl',
#   'night',
#   'for',
#   'the',
#   'next',
#   'year',
#   'at',
#   'least'],
#  ['deputi',
#   ':',
#   'man',
#   'shot',
#   'befor',
#   'brighton',
#   'home',
#   'set',
#   'ablaz',
#   ':'],
#  ['man',
#   'wife',
#   'get',
#   'six',
#   'year',
#   'jail',
#   'for',
#   'set',
#   'ablaz',
#   'niec',
#   ':'],
#  ['santa', 'cruz'],
#  ['polic',
#   ':',
#   'arsonist',
#   'deliber',
#   'set',
#   'black',
#   'church',
#   'in',
#   'north',
#   'carolinaåêablaz',
#   ':'],
#  ['noch',
#   'elbestia',
#   "'",
#   ':',
#   'happi',
#   'to',
#   'see',
#   'my',
#   'teammat',
#   'and',
#   'train',
#   'hard',
#   '?',
#   '?',
#   'goodnight',
#   'gunner',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   ':'],
#  ['kurd',
#   'trampl',
#   'on',
#   'turkmen',
#   'flag',
#   'later',
#   'set',
#   'it',
#   'ablaz',
#   'while',
#   'other',
#   'vandal',
#   'offic',
#   'of',
#   'turkmen',
#   'front',
#   'in',
#   'diyala',
#   ':'],
#  ['truck',
#   'ablaz',
#   ':',
#   'r',
#   'voortrekk',
#   'ave',
#   'outsid',
#   'or',
#   'tambo',
#   'intl',
#   'cargo',
#   'section',
#   ':'],
#  ['set',
#   'our',
#   'heart',
#   'ablaz',
#   'and',
#   'everi',
#   'citi',
#   'wa',
#   'a',
#   'gift',
#   'and',
#   'everi',
#   'skylin',
#   'wa',
#   'like',
#   'a',
#   'kiss',
#   'upon',
#   'the',
#   'lip',
#   '@'],
#  ['they',
#   'sky',
#   'wa',
#   'ablaz',
#   'tonight',
#   'in',
#   'lo',
#   'angel',
#   'i',
#   "'m",
#   'expect',
#   'ig',
#   'and',
#   'fb',
#   'to',
#   'be',
#   'fill',
#   'with',
#   'sunset',
#   'shot',
#   'if',
#   'i',
#   'know',
#   'my',
#   'peep',
#   '!',
#   '!'],
#  ['how',
#   'the',
#   'west',
#   'wa',
#   'burn',
#   ':',
#   'thousand',
#   'of',
#   'wildfir',
#   'ablaz',
#   'in',
#   'california',
#   'alon',
#   ':'],
#  ['revel',
#   'in',
#   'your',
#   'wmv',
#   'video',
#   'by',
#   'mean',
#   'of',
#   'mac',
#   'farewel',
#   'ablaz',
#   'wmv',
#   'en',
#   'rout',
#   'to',
#   'dvd',
#   ':',
#   'gtxrwm'],
#  ['progress',
#   'greet',
#   '!',
#   'in',
#   'about',
#   'a',
#   'month',
#   'student',
#   'would',
#   'have',
#   'set',
#   'their',
#   'pen',
#   'ablaz',
#   'in',
#   'the',
#   'torch',
#   'public',
#   "'",
#   ':'],
#  ['rene',
#   'ablaz',
#   '&',
#   'amp',
#   'jacinta',
#   'secret',
#   'k',
#   '(',
#   'fallen',
#   'sky',
#   'edit',
#   ')',
#   'mar',
#   's',
#   ':'],
#  ['steve',
#   'these',
#   'fire',
#   'out',
#   'here',
#   'are',
#   'someth',
#   'els',
#   '!',
#   'california',
#   'is',
#   'a',
#   'tinderbox',
#   'and',
#   'thi',
#   'clown',
#   'wa',
#   'set',
#   'my',
#   "'hood",
#   'ablaz'],
#  ['nowplay', ':', 'rene', 'ablaz', '&', 'amp', 'ian', 'buff', 'magnitud', ':'],
#  ['huge', 'fire', 'at', 'wholesal', 'market', 'ablaz', ':'],
#  ['what',
#   'time',
#   'doe',
#   'your',
#   'talk',
#   'go',
#   'until',
#   '?',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'if',
#   'i',
#   'can',
#   'make',
#   'it',
#   'due',
#   'to',
#   'work'],
#  ["'",
#   'i',
#   'ca',
#   "n't",
#   'have',
#   'kid',
#   'cuz',
#   'i',
#   'got',
#   'in',
#   'a',
#   'bicycl',
#   'accid',
#   '&',
#   'amp',
#   'split',
#   'my',
#   'testicl',
#   'it',
#   "'s",
#   'imposs',
#   'for',
#   'me',
#   'to',
#   'have',
#   'kid',
#   "'",
#   'michael',
#   'you',
#   'are',
#   'the',
#   'father'],
#  ['accid',
#   'on',
#   'i',
#   'w',
#   'nashvilletraff',
#   'traffic',
#   'move',
#   'm',
#   'slower',
#   'than',
#   'usual',
#   's',
#   ':'],
#  ['accid',
#   'center',
#   'lane',
#   'block',
#   'in',
#   'santaclara',
#   'on',
#   'us',
#   'nb',
#   'befor',
#   'great',
#   'america',
#   'pkwi',
#   'bayarea',
#   'traffic',
#   ':'],
#  [':'],
#  ['stloui',
#   'caraccidentlawy',
#   'speed',
#   'among',
#   'top',
#   'caus',
#   'of',
#   'teen',
#   'accid',
#   's',
#   ':'],
#  ['report',
#   'motor',
#   'vehicl',
#   'accid',
#   'in',
#   'curri',
#   'on',
#   'herman',
#   'rd',
#   'near',
#   'stephenson',
#   'involv',
#   'an',
#   'overturn',
#   'vehicl',
#   'pleas',
#   'use',
#   ':'],
#  ['bigrigradio', 'live', 'accid', 'awar'],
#  ['i',
#   'mile',
#   'marker',
#   'south',
#   'mooresvil',
#   'iredel',
#   'vehicl',
#   'accid',
#   'ramp',
#   'close',
#   'at',
#   ':',
#   'pm'],
#  ['rt',
#   ':',
#   'sleep',
#   'pill',
#   'doubl',
#   'your',
#   'risk',
#   'of',
#   'a',
#   'car',
#   'accid',
#   ':'],
#  ["'bi",
#   'accid',
#   "'",
#   'they',
#   'knew',
#   'what',
#   'wa',
#   'gon',
#   'happen',
#   's',
#   ':'],
#  ['traffic',
#   'accid',
#   'n',
#   'cabrillo',
#   'hwymagellan',
#   'av',
#   'mir',
#   '(',
#   ':',
#   ':',
#   ')'],
#  ['i',
#   'mile',
#   'marker',
#   'to',
#   'south',
#   'mooresvil',
#   'iredel',
#   'vehicl',
#   'accid',
#   'congest',
#   'at',
#   ':',
#   'pm'],
#  ['the',
#   'pastor',
#   'wa',
#   'not',
#   'in',
#   'the',
#   'scene',
#   'of',
#   'the',
#   'accidentwho',
#   'wa',
#   'the',
#   'owner',
#   'of',
#   'the',
#   'rang',
#   'rover',
#   '?'],
#  ['mom',
#   ':',
#   "'we",
#   'did',
#   "n't",
#   'get',
#   'home',
#   'as',
#   'fast',
#   'as',
#   'we',
#   'wish',
#   "'",
#   'me',
#   ':',
#   "'whi",
#   'is',
#   'that',
#   '?',
#   "'",
#   'mom',
#   ':',
#   "'there",
#   'wa',
#   'an',
#   'accid',
#   'and',
#   'some',
#   'truck',
#   'spilt',
#   'mayonnais',
#   'all',
#   'over',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['i',
#   'wa',
#   'in',
#   'a',
#   'horribl',
#   'car',
#   'accid',
#   'thi',
#   'past',
#   'sunday',
#   'i',
#   "'m",
#   'final',
#   'abl',
#   'to',
#   'get',
#   'around',
#   'thank',
#   'you',
#   'god',
#   '?',
#   '?'],
#  ['can',
#   'wait',
#   'to',
#   'see',
#   'how',
#   'piss',
#   'donni',
#   'is',
#   'when',
#   'i',
#   'tell',
#   'him',
#   'i',
#   'wa',
#   'in',
#   'anoth',
#   'accid',
#   '?',
#   '?'],
#  ['truckcrash', 'overturn', 'on', 'fortworth', 'interst', ':'],
#  ['accid', 'in', 'ashvil', 'on', 'us', 'sb', 'befor', 'sr', 'traffic', ':'],
#  ['carolina',
#   'accid',
#   ':',
#   'motorcyclist',
#   'die',
#   'in',
#   'i',
#   'crash',
#   'with',
#   'car',
#   'that',
#   'cross',
#   'median',
#   ':',
#   'a',
#   'motorcycl',
#   'rider',
#   'travel',
#   ':'],
#  ['fyi',
#   'cad',
#   ':',
#   'fyi',
#   ':',
#   'accid',
#   'properti',
#   'damagenh',
#   'piner',
#   'rdhorndal',
#   'dr'],
#  ['rt',
#   'naayf',
#   ':',
#   'first',
#   'accid',
#   'in',
#   'year',
#   'turn',
#   'onto',
#   'chandane',
#   'magu',
#   'from',
#   'near',
#   'mma',
#   'taxi',
#   'ram',
#   'into',
#   'me',
#   'while',
#   'i',
#   'wa',
#   'halfway',
#   'turn',
#   'everyon',
#   'conf'],
#  ['accid',
#   'left',
#   'lane',
#   'block',
#   'in',
#   'manchest',
#   'on',
#   'rt',
#   'nb',
#   'befor',
#   'eddi',
#   'rd',
#   'stop',
#   'and',
#   'go',
#   'traffic',
#   'back',
#   'to',
#   'nha',
#   'delay',
#   'of',
#   'min',
#   'traffic'],
#  ['accid', 'properti', 'damag', 'piner', 'rdhorndal', 'dr'],
#  ['?', '?', '?', '?', 'it', 'wa', 'an', 'accid', ':'],
#  ['fyi',
#   'cad',
#   ':',
#   'fyi',
#   ':',
#   'accid',
#   'properti',
#   'damagewpd',
#   's',
#   'th',
#   'st'],
#  ['@',
#   ':',
#   'pm',
#   ':',
#   'traffic',
#   'accid',
#   'no',
#   'injuri',
#   'at',
#   'willi',
#   'foreman',
#   'rd',
#   ':'],
#  ['aashiqui',
#   'actress',
#   'anu',
#   'aggarw',
#   'on',
#   'her',
#   'nearfat',
#   'accid',
#   ':'],
#  ['suffield', 'alberta', 'accid', 's', ':'],
#  ['mile',
#   'backup',
#   'on',
#   'i',
#   'southaccid',
#   'block',
#   'the',
#   'right',
#   'lane',
#   'at',
#   'exit',
#   'langtre',
#   'rdconsid',
#   'nc',
#   'or',
#   'nc',
#   'to',
#   'nc',
#   'as',
#   'altern'],
#  ['ha',
#   'an',
#   'accid',
#   'chang',
#   'your',
#   'life',
#   '?',
#   'we',
#   'will',
#   'help',
#   'you',
#   'determin',
#   'option',
#   'that',
#   'can',
#   'financi',
#   'support',
#   'life',
#   'care',
#   'plan',
#   'and',
#   'ongo',
#   'treatment'],
#  ['break',
#   ':',
#   'there',
#   'wa',
#   'a',
#   'deadli',
#   'motorcycl',
#   'car',
#   'accid',
#   'that',
#   'happen',
#   'to',
#   'hagerstown',
#   'today',
#   'i',
#   "'ll",
#   'have',
#   'more',
#   'detail',
#   'at',
#   'state',
#   'whag'],
#  ['were', 'you', 'marinad', 'it', 'or', 'wa', 'it', 'an', 'accid', '?'],
#  ['onli',
#   'had',
#   'a',
#   'car',
#   'for',
#   'not',
#   'even',
#   'a',
#   'week',
#   'and',
#   'got',
#   'in',
#   'a',
#   'fuck',
#   'car',
#   'accid',
#   'mf',
#   'ca',
#   "n't",
#   'fuck',
#   'drive'],
#  ['bahrain',
#   'polic',
#   'had',
#   'previous',
#   'die',
#   'in',
#   'a',
#   'road',
#   'accid',
#   'they',
#   'were',
#   'not',
#   'kill',
#   'by',
#   'explos',
#   's',
#   ':'],
#  ['i',
#   'still',
#   'have',
#   'not',
#   'heard',
#   'church',
#   'leader',
#   'of',
#   'kenya',
#   'come',
#   'forward',
#   'to',
#   'comment',
#   'on',
#   'the',
#   'accid',
#   'issu',
#   'and',
#   'disciplinari',
#   'measuresarrestpastornganga'],
#  ['scuf', 'ps', 'live', 'and', 'the', 'game', 'cya'],
#  ["'the",
#   'man',
#   'who',
#   'can',
#   'drive',
#   'himself',
#   'further',
#   'onc',
#   'the',
#   'effort',
#   'get',
#   'pain',
#   'is',
#   'the',
#   'man',
#   'who',
#   'will',
#   'win',
#   "'",
#   'roger',
#   'bannist'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ["'there",
#   'is',
#   'no',
#   'victori',
#   'at',
#   'bargain',
#   'basement',
#   'price',
#   "'",
#   'dwight',
#   'david',
#   'eisenhow'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ["'nobodi", 'rememb', 'who', 'came', 'in', 'second', "'", 'charl', 'schulz'],
#  ['im',
#   'speak',
#   'from',
#   'someon',
#   'that',
#   'is',
#   'use',
#   'a',
#   'scuf',
#   'on',
#   'xb',
#   'most',
#   'of',
#   'them',
#   'peopl',
#   'will',
#   'end',
#   'up',
#   'get',
#   'on',
#   'for',
#   'ps',
#   'also'],
#  ["'the",
#   'harder',
#   'the',
#   'conflict',
#   'the',
#   'more',
#   'gloriou',
#   'the',
#   'triumph',
#   "'",
#   'thoma',
#   'pain'],
#  ['growingupspoil',
#   'go',
#   'clay',
#   'pigeon',
#   'shoot',
#   'and',
#   'cri',
#   'becaus',
#   'of',
#   'the',
#   "'aftershock",
#   "'"],
#  ['so',
#   'i',
#   'guess',
#   'no',
#   'one',
#   'actual',
#   'want',
#   'ani',
#   'free',
#   'aftershock',
#   'tc'],
#  ['aftershock',
#   'wa',
#   'the',
#   'most',
#   'terrifi',
#   'best',
#   'roller',
#   'coaster',
#   'i',
#   "'ve",
#   'ever',
#   'been',
#   'on',
#   'disclaim',
#   'i',
#   "'ve",
#   'been',
#   'on',
#   'veri',
#   'few'],
#  ['aftershock', 's', ':'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ['i', "'m", 'see', 'them', 'and', 'issu', 'at', 'aftershock', '?', '?'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ['[', 'ir', ']', 'icemoon', '[', 'aftershock', ']', ':'],
#  ['wisdomw',
#   'bonu',
#   'minut',
#   'daili',
#   'habit',
#   'that',
#   'could',
#   'realli',
#   'improv',
#   'your',
#   'life',
#   'how',
#   'mani',
#   'do',
#   'you',
#   'alreadi',
#   'do',
#   '?',
#   'lifehack',
#   ':'],
#  ['aftershock',
#   ':',
#   'protect',
#   'yourself',
#   'and',
#   'profit',
#   'in',
#   'the',
#   'next',
#   'global',
#   'financi',
#   'meltdown',
#   'by',
#   'david',
#   'wiedem',
#   ':'],
#  ['that',
#   'moment',
#   'when',
#   'you',
#   'get',
#   'on',
#   'a',
#   'scari',
#   'roller',
#   'coaster',
#   'and',
#   'the',
#   'guy',
#   'behind',
#   'you',
#   'is',
#   'just',
#   'scream',
#   'bloodi',
#   'murder',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   'silverwood',
#   'aftershock'],
#  ['aftershock'],
#  ['&',
#   'gt',
#   '&',
#   'gt',
#   '$',
#   'aftershock',
#   ':',
#   'protect',
#   'yourself',
#   'and',
#   'profit',
#   'in',
#   'the',
#   'next',
#   'global',
#   'financi',
#   'book',
#   ':'],
#  ['sometim',
#   'you',
#   'face',
#   'difficulti',
#   'not',
#   'becaus',
#   'you',
#   "'re",
#   'do',
#   'someth',
#   'wrong',
#   'but',
#   'becaus',
#   'you',
#   "'re",
#   'do',
#   'someth',
#   'right',
#   'joel',
#   'osteen'],
#  ["'the",
#   'onli',
#   'thing',
#   'that',
#   'stand',
#   'between',
#   'you',
#   'and',
#   'your',
#   'dream',
#   'is',
#   'the',
#   'will',
#   'to',
#   'tri',
#   'and',
#   'the',
#   'belief',
#   'that',
#   'it',
#   'is',
#   'actual',
#   'possibl',
#   "'",
#   'joel',
#   'brown'],
#  ['prais',
#   'god',
#   'that',
#   'we',
#   'have',
#   'ministri',
#   'that',
#   'tell',
#   'it',
#   'like',
#   'it',
#   'is',
#   '!',
#   '!',
#   '!',
#   'now',
#   'wdyouth',
#   'biblestudi',
#   's',
#   ':'],
#  ["'rememb",
#   'that',
#   'you',
#   'are',
#   'go',
#   'to',
#   'die',
#   'is',
#   'the',
#   'best',
#   'way',
#   'i',
#   'know',
#   'to',
#   'avoid',
#   'the',
#   'trap',
#   'of',
#   'think',
#   'you',
#   'have',
#   'someth',
#   'to',
#   'lose',
#   "'"],
#  ['tri',
#   'orang',
#   'aftershock',
#   'today',
#   'my',
#   'life',
#   'will',
#   'never',
#   'be',
#   'the',
#   'same'],
#  ['i', 'love', 'you', 'bb'],
#  ['aftershock', 's', ':'],
#  ['aftershock',
#   'back',
#   'to',
#   'school',
#   'kick',
#   'off',
#   'wa',
#   'great',
#   'i',
#   'want',
#   'to',
#   'thank',
#   'everyon',
#   'for',
#   'make',
#   'it',
#   'possibl',
#   'what',
#   'a',
#   'great',
#   'night'],
#  ['peopl',
#   'who',
#   'say',
#   'it',
#   'can',
#   'not',
#   'be',
#   'done',
#   'should',
#   'not',
#   'interrupt',
#   'those',
#   'who',
#   'are',
#   'do',
#   'it'],
#  ["'the",
#   'first',
#   'man',
#   'get',
#   'the',
#   'oyster',
#   'the',
#   'second',
#   'man',
#   'get',
#   'the',
#   'shell',
#   "'",
#   'andrew',
#   'carnegi'],
#  ['anyon',
#   'need',
#   'a',
#   'pu',
#   'tonight',
#   '?',
#   'i',
#   'play',
#   'hybrid',
#   'slayer',
#   'ps',
#   'eu',
#   'hmu',
#   'sandscrim',
#   '@',
#   'tpkotc',
#   '@',
#   'tpfa'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'o',
#   ':'],
#  ['strict',
#   'liabil',
#   'in',
#   'the',
#   'context',
#   'of',
#   'an',
#   'airplan',
#   'accid',
#   ':',
#   'pilot',
#   'error',
#   'is',
#   'a',
#   'common',
#   'compon',
#   'of',
#   'most',
#   'aviat',
#   'cr',
#   ':'],
#  ['your',
#   'lifetim',
#   'odd',
#   'of',
#   'die',
#   'from',
#   'an',
#   'airplan',
#   'accid',
#   'are',
#   'in'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'on',
#   'wedn',
#   ':'],
#  ['awwww',
#   'they',
#   "'re",
#   'on',
#   'an',
#   'airplan',
#   'accid',
#   'and',
#   'they',
#   "'re",
#   'gon',
#   'na',
#   'die',
#   'what',
#   'a',
#   'cuti',
#   '?',
#   '?',
#   '?',
#   '?',
#   'good',
#   'job',
#   '!'],
#  ['famili',
#   'member',
#   'of',
#   'osama',
#   'bin',
#   'laden',
#   'have',
#   'die',
#   'in',
#   'an',
#   'airplan',
#   'accid',
#   'how',
#   'iron',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   'mhmmm',
#   'gov',
#   'shit',
#   'i',
#   'suspect'],
#  ['man', 'goe', 'into', 'airplan', 'engin', 'accid', ':', ':'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'in',
#   'wing',
#   'of',
#   'airplan',
#   '(',
#   ')',
#   ':'],
#  ['a',
#   'cessna',
#   'airplan',
#   'accid',
#   'in',
#   'ocampo',
#   'coahuila',
#   'mexico',
#   'on',
#   'juli',
#   'kill',
#   'four',
#   'men',
#   'includ',
#   'a',
#   'state',
#   'of',
#   'coahuila',
#   'govern',
#   'offici'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'in',
#   'wing',
#   'airplan',
#   '(',
#   ')',
#   'watchthevideo',
#   ':'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'on',
#   'wednesday',
#   'began',
#   'examin',
#   't'],
#  ['kca',
#   'votejktid',
#   'mbataweel',
#   ':',
#   'rip',
#   'binladen',
#   'famili',
#   'member',
#   'who',
#   'kill',
#   'in',
#   'an',
#   'airplan',
#   "'s",
#   'accid'],
#  ['i',
#   'almost',
#   'sent',
#   'my',
#   'cowork',
#   'nude',
#   'on',
#   'accid',
#   'thank',
#   'god',
#   'for',
#   'airplan',
#   'mode'],
#  ['that',
#   'or',
#   'they',
#   'might',
#   'be',
#   'kill',
#   'in',
#   'an',
#   'airplan',
#   'accid',
#   'in',
#   'the',
#   'night',
#   'a',
#   'car',
#   'wreck',
#   '!',
#   'polit',
#   'at',
#   'it',
#   "'s",
#   'best'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'on',
#   ':'],
#  ['thi',
#   'is',
#   'unbeliev',
#   'insan',
#   'man',
#   'airport',
#   'airplan',
#   'aircraft',
#   'aeroplan',
#   'runway',
#   'accid',
#   'freaki'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'in',
#   'wing',
#   'of',
#   'airplaneåê',
#   '(',
#   ')',
#   ':'],
#  ['horribl',
#   'accid',
#   'man',
#   'die',
#   'in',
#   'wing',
#   'of',
#   'airplan',
#   '(',
#   ')',
#   ':'],
#  ['usama',
#   'bin',
#   'ladin',
#   'famili',
#   'dead',
#   'in',
#   'airplan',
#   'crash',
#   'natur',
#   'no',
#   'accid'],
#  ['pilot', 'die', 'in', 'plane', 'crash', 'at', 'car', 'festiv', 's', ':'],
#  ['strict',
#   'liabil',
#   'in',
#   'the',
#   'context',
#   'of',
#   'an',
#   'airplan',
#   'accid',
#   ':'],
#  ['dtn',
#   'brazil',
#   ':',
#   'expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'exp',
#   ':'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'on',
#   'wedn',
#   ':'],
#  ['horribl', 'accid', 'man', 'die', 'in', 'wing', 'of'],
#  ['nicol',
#   'fletcher',
#   'one',
#   'of',
#   'a',
#   'victim',
#   'of',
#   'crash',
#   'airplan',
#   'few',
#   'time',
#   'ago',
#   'the',
#   'accid',
#   'left',
#   'a',
#   'littl',
#   'bit',
#   'trauma',
#   'for',
#   'her',
#   'although',
#   'she',
#   "'s"],
#  ['omg', 'horribl', 'accid', 'man', 'die', 'in', 'wing', 'of', 'airplan', ':'],
#  ['omg',
#   '!',
#   'i',
#   'do',
#   "n't",
#   'believ',
#   'thi',
#   'rip',
#   'bro',
#   'airplan',
#   'accid',
#   'jetengin',
#   'turbojet',
#   'bo',
#   'g',
#   ':'],
#  ['expert',
#   'in',
#   'franc',
#   'begin',
#   'examin',
#   'airplan',
#   'debri',
#   'found',
#   'on',
#   'reunion',
#   'island',
#   ':',
#   'french',
#   'air',
#   'accid',
#   'expert',
#   'on',
#   'wednesday',
#   'began',
#   'examin',
#   't'],
#  ['i', 'had', 'a', 'airplan', 'accid'],
#  ['my',
#   'phone',
#   'look',
#   'like',
#   'it',
#   'wa',
#   'in',
#   'a',
#   'car',
#   'ship',
#   'airplan',
#   'accid',
#   'terribl'],
#  ['statist',
#   'i',
#   "'m",
#   'at',
#   'more',
#   'of',
#   'risk',
#   'of',
#   'get',
#   'kill',
#   'by',
#   'a',
#   'cop',
#   'than',
#   'i',
#   'am',
#   'of',
#   'die',
#   'in',
#   'an',
#   'airplan',
#   'accid'],
#  ['airplan',
#   'crash',
#   'on',
#   'hous',
#   'in',
#   'colombia',
#   'peopl',
#   'die',
#   'in',
#   'accid',
#   's',
#   ':'],
#  ['the', 'shoot', 'or', 'the', 'airplan', 'accid', 's', ':'],
#  ['could',
#   'a',
#   'drone',
#   'caus',
#   'an',
#   'airplan',
#   'accid',
#   '?',
#   'pilot',
#   'worri',
#   'about',
#   'use',
#   'of',
#   'drone',
#   'esp',
#   'in',
#   'close',
#   'vicin',
#   'of',
#   'airport',
#   ':'],
#  ['earli',
#   'wake',
#   'up',
#   'call',
#   'from',
#   'my',
#   'sister',
#   'beg',
#   'me',
#   'to',
#   'come',
#   'over',
#   '&',
#   'amp',
#   'ride',
#   'wher',
#   'in',
#   'the',
#   'ambul',
#   'to',
#   'the',
#   'hospit',
#   'rodkiai'],
#  [':'],
#  ['two',
#   'air',
#   'ambul',
#   'on',
#   'scene',
#   'of',
#   'seriou',
#   'crash',
#   'between',
#   'two',
#   'car',
#   'and',
#   'lorri',
#   'in',
#   ':'],
#  ['twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   'reuter',
#   ':'],
#  ['lead', 'emerg', 'servic', 'boss', 'welcom', 'new', 'ambul', 'chariti', ':'],
#  ['anyon',
#   'travel',
#   'aberystwythshrewsburi',
#   'right',
#   'now',
#   'there',
#   "'s",
#   'been',
#   'an',
#   'incid',
#   'servic',
#   'at',
#   'a',
#   'halt',
#   'just',
#   'outsid',
#   'shrew',
#   'ambul',
#   'on',
#   'scene'],
#  ['twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   ':'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   'of',
#   'lez',
#   'compliant',
#   'ebay',
#   ':'],
#  ['new',
#   'nanotech',
#   'devic',
#   'will',
#   'be',
#   'abl',
#   'to',
#   'target',
#   'and',
#   'destroy',
#   'blood',
#   'clot',
#   ':'],
#  ['@',
#   'skyhawkmm',
#   'it',
#   'wa',
#   'hella',
#   'crazi',
#   'fight',
#   'an',
#   'ambul',
#   'and',
#   'a',
#   'coupl',
#   'mosh',
#   'pit',
#   '?',
#   '?'],
#  ['if',
#   'i',
#   'get',
#   'run',
#   'over',
#   'by',
#   'an',
#   'ambul',
#   'am',
#   'i',
#   'lucki',
#   '?',
#   'justsay',
#   'randomthought'],
#  ['news',
#   'twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   ':'],
#  [':'],
#  ['wait', 'for', 'an', 'ambul'],
#  ['you',
#   'ok',
#   '?',
#   'need',
#   'a',
#   'ambul',
#   'hahahah',
#   'that',
#   'wa',
#   'good',
#   '!',
#   ':'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   'of',
#   'lez',
#   'compliant',
#   'ebay',
#   ':'],
#  ['pakistan', 'air', 'ambul', 'helicopt', 'crash', 'kill', 'nine', ':'],
#  ['nissan',
#   'are',
#   'you',
#   'ok',
#   'do',
#   'you',
#   'need',
#   'medic',
#   'assist',
#   'i',
#   'can',
#   'call',
#   'an',
#   'ambul',
#   'if',
#   'you',
#   'need',
#   'me',
#   'to'],
#  ['em', ':', 'ny', 'emt', 'petit', 'for', '$', 'per', 'hour'],
#  [':'],
#  ['twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   ':'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   'of',
#   'lez',
#   'compliant',
#   'ebay',
#   ':'],
#  ['ambul',
#   'sprinter',
#   'automat',
#   'frontlin',
#   'vehicl',
#   'choic',
#   'of',
#   'lez',
#   'compliant',
#   'ebay',
#   ':'],
#  ['check',
#   'out',
#   'what',
#   "'s",
#   'in',
#   'my',
#   'park',
#   'lot',
#   '!',
#   '!',
#   'he',
#   'said',
#   'that',
#   'until',
#   'last',
#   'year',
#   'it',
#   'wa',
#   'an',
#   'ambul',
#   'in',
#   'st',
#   'john',
#   ':'],
#  ['when',
#   'you',
#   'do',
#   "n't",
#   'know',
#   'which',
#   'way',
#   'an',
#   'ambul',
#   'is',
#   'come',
#   'from',
#   '&',
#   'lt',
#   '&',
#   'lt'],
#  ['reuter',
#   'twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   ':'],
#  [':'],
#  ['whi', 'is', 'there', 'an', 'ambul', 'right', 'outsid', 'my', 'work'],
#  [],
#  ['happen',
#   'now',
#   'hatzolah',
#   'em',
#   'ambul',
#   'respond',
#   'with',
#   'dual',
#   'siren',
#   'and'],
#  [':'],
#  [':'],
#  ['twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   ':'],
#  ['twelv',
#   'fear',
#   'kill',
#   'in',
#   'pakistani',
#   'air',
#   'ambul',
#   'helicopt',
#   'crash',
#   ':'],
#  ['what',
#   "'s",
#   'the',
#   'polic',
#   'or',
#   'ambul',
#   'number',
#   'in',
#   'lesotho',
#   '?',
#   'ani',
#   'bodi',
#   'know',
#   '?'],
#  ['i',
#   'am',
#   'surpris',
#   'we',
#   'still',
#   'can',
#   'not',
#   'standardis',
#   'the',
#   'clinic',
#   'practic',
#   'across',
#   'the',
#   'nh',
#   'ambul',
#   'trust'],
#  [':'],
#  ['peopl',
#   'who',
#   'tri',
#   'to',
#   'jwalk',
#   'while',
#   'an',
#   'ambul',
#   'is',
#   'pass',
#   'i',
#   'hate',
#   'you'],
#  ['the',
#   'episod',
#   'where',
#   'trunk',
#   'annihil',
#   'freiza',
#   'is',
#   'the',
#   'cleanest',
#   'shit',
#   'ever',
#   'he',
#   'show',
#   'that',
#   'nigga',
#   'no',
#   'merci'],
#  ['they',
#   'shall',
#   'be',
#   'annihil',
#   'and',
#   'all',
#   'of',
#   'their',
#   'petebest',
#   'dessic',
#   'and',
#   'laid',
#   'bare',
#   'then',
#   'you',
#   'shall',
#   'kneel',
#   'befor',
#   'me'],
#  ['urib', 'just', 'annihil', 'that', 'basebal', 'met'],
#  ['hey',
#   '!',
#   'sundown',
#   'were',
#   'annihil',
#   'in',
#   'their',
#   'previou',
#   'meet',
#   'with',
#   'celticinde',
#   'it',
#   'an',
#   'improv'],
#  ['mizzou',
#   'ha',
#   'annihil',
#   'florida',
#   'the',
#   'past',
#   'season',
#   'even',
#   'end',
#   'muschamp',
#   "'s",
#   'career',
#   'just',
#   'ca',
#   "n't",
#   'compet',
#   'with',
#   'bama'],
#  ['annihil', 'ab', '?', '?', ':'],
#  ['be',
#   'annihil',
#   'for',
#   'statu',
#   'educ',
#   'mba',
#   'on',
#   'behalf',
#   'of',
#   'a',
#   'on',
#   'easi',
#   'street',
#   'careen',
#   ':',
#   'eovm',
#   ':'],
#  ['to',
#   'luka',
#   'they',
#   'should',
#   'all',
#   'die',
#   '!',
#   'all',
#   'of',
#   'them',
#   '!',
#   'everyth',
#   'annihil',
#   '!',
#   'aloi',
#   'tranci'],
#  ['have',
#   'a',
#   'good',
#   'un',
#   'fella',
#   'sorri',
#   'i',
#   'wo',
#   "n't",
#   'be',
#   'there',
#   'to',
#   'get',
#   'annihil',
#   'with',
#   'you',
#   ':',
#   '('],
#  ['cop',
#   'pull',
#   'drunk',
#   'driver',
#   'to',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'is',
#   'hit',
#   'by',
#   'train',
#   ':'],
#  ['you', 'must', 'be', 'annihil', '!'],
#  ['cop',
#   'pull',
#   'drunk',
#   'driver',
#   'to',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'is',
#   'hit',
#   'by',
#   'train',
#   ':'],
#  ['boom',
#   '!',
#   'your',
#   'countri',
#   'wa',
#   'just',
#   'entir',
#   'annihil',
#   'by',
#   'a',
#   'h'],
#  ['you',
#   'would',
#   'have',
#   'been',
#   'annihil',
#   'so',
#   'you',
#   'might',
#   'as',
#   'well',
#   'thank'],
#  ['one',
#   'thing',
#   'for',
#   'suregod',
#   'ha',
#   'promis',
#   'israel',
#   'will',
#   'not',
#   'be',
#   'annihil',
#   'butth',
#   'horror',
#   'of',
#   'iran',
#   'wnuke',
#   's',
#   ':'],
#  ['i',
#   'guess',
#   'that',
#   "'s",
#   'ok',
#   'for',
#   'armenian',
#   'sinc',
#   'we',
#   "'ve",
#   'spent',
#   'most',
#   'of',
#   'our',
#   'histori',
#   'get',
#   'annihil'],
#  ['year',
#   'sinc',
#   'we',
#   'annihil',
#   'peopl',
#   'instantli',
#   'and',
#   'becam',
#   'awar',
#   'that',
#   'we',
#   'have',
#   'the',
#   'abil',
#   'to',
#   'annihil',
#   'the',
#   'whole',
#   'of',
#   'human'],
#  ['day',
#   'of',
#   'tryout',
#   'went',
#   'good',
#   'minu',
#   'the',
#   'fact',
#   'i',
#   'stop',
#   'quickli',
#   'to',
#   'get',
#   'a',
#   'short',
#   'ball',
#   'and',
#   'annihil',
#   'my',
#   'toenail',
#   'injuri',
#   'even',
#   'more'],
#  ['dure',
#   'the',
#   's',
#   'the',
#   'oryx',
#   'a',
#   'symbol',
#   'of',
#   'the',
#   'arabian',
#   'peninsula',
#   'were',
#   'annihil',
#   'by',
#   'hunter',
#   ':'],
#  ['(',
#   'to',
#   'luka',
#   ')',
#   "'they",
#   'should',
#   'all',
#   'die',
#   '!',
#   'all',
#   'of',
#   'them',
#   '!',
#   'everyth',
#   'annihil',
#   '!',
#   "'",
#   'aloi',
#   'tranci'],
#  ['readi', 'to', 'get', 'annihil', 'for', 'the', 'buc', 'game'],
#  ['peopl',
#   "'annihil",
#   'by',
#   'last',
#   'night',
#   'weather',
#   "'",
#   'realli',
#   'philip',
#   'thought',
#   'you',
#   'would',
#   'have',
#   'forecast',
#   'that'],
#  ['domain',
#   'other',
#   'sophist',
#   'be',
#   'annihil',
#   'close',
#   'uptotheminut',
#   'feat',
#   ':',
#   'zrnf'],
#  ['i',
#   'seen',
#   'juda',
#   'priest',
#   'in',
#   'when',
#   'rob',
#   'came',
#   'back',
#   'scorpion',
#   'as',
#   'support',
#   'fuck',
#   'annihil',
#   'the',
#   'place',
#   'astonish',
#   'gig'],
#  ['offici',
#   'skip',
#   'out',
#   'on',
#   'fantasticfourfantsticwhatev',
#   'the',
#   'hashtag',
#   'is',
#   'it',
#   "'s",
#   'get',
#   'annihil',
#   'in',
#   'review',
#   'bummer'],
#  ['thu',
#   'explain',
#   'whi',
#   'you',
#   'were',
#   'all',
#   'annihil',
#   'but',
#   'the',
#   'few',
#   'or',
#   'in',
#   'thi',
#   'case',
#   'you',
#   'the',
#   'onli',
#   'survivor',
#   'evolv',
#   'and',
#   'becam',
#   'godlik'],
#  ['just',
#   'complet',
#   'annihil',
#   'cech',
#   'with',
#   'paul',
#   'keegan',
#   'what',
#   'a',
#   'time',
#   'to',
#   'be',
#   'aliv'],
#  ["'who",
#   'then',
#   'were',
#   'annihil',
#   'by',
#   'the',
#   'legion',
#   'itself',
#   'the',
#   'survivor',
#   'of',
#   'the',
#   'imperfect',
#   'hybrid',
#   'project',
#   'quickli',
#   'form',
#   'a',
#   'new',
#   'secret',
#   'cell'],
#  ['exactli',
#   'that',
#   "'s",
#   'whi',
#   'the',
#   'lesnarcena',
#   'match',
#   'from',
#   'summerslam',
#   'last',
#   'year',
#   'wa',
#   'so',
#   'great',
#   'becaus',
#   'brock',
#   'annihil',
#   'a',
#   'guy',
#   'who',
#   "'s"],
#  ['cop',
#   'pull',
#   'drunk',
#   'driver',
#   'to',
#   'safeti',
#   'second',
#   'befor',
#   'hi',
#   'car',
#   'is',
#   'hit',
#   'by',
#   'train',
#   ':'],
#  ['annihil', 'in', 'damascu', ':', 'syrian', 'armi', 'grind', ':'],
#  ['ok',
#   'i',
#   'wa',
#   "n't",
#   'complet',
#   'forthright',
#   'i',
#   'may',
#   'have',
#   'also',
#   'been',
#   'in',
#   'a',
#   'food',
#   'coma',
#   'bc',
#   'of',
#   'the',
#   'kebabtahinipickl',
#   'i',
#   'also',
#   'annihil',
#   'wfri'],
#  ['a',
#   'fun',
#   'fill',
#   'happyhour',
#   'at',
#   'simmon',
#   'bar',
#   'in',
#   'camden',
#   'with',
#   'thi',
#   'handsom',
#   'one',
#   '?',
#   '?',
#   '(',
#   'i',
#   'got',
#   'annihil',
#   'apart',
#   'from',
#   'thi',
#   'game',
#   ')',
#   ':'],
#  ['juanni', 'beisbol', 'sr', 'annihil', 'that', 'ball', 'lgm'],
#  ['hell',
#   'is',
#   'just',
#   'a',
#   'fraction',
#   'of',
#   'hi',
#   'belief',
#   'of',
#   'total',
#   'annihil',
#   'destruct',
#   'of',
#   'usa'],
#  ['mayb',
#   'we',
#   'should',
#   'call',
#   'israel',
#   'and',
#   'tell',
#   'them',
#   'we',
#   "'re",
#   'sorri',
#   'are',
#   'pre',
#   'ha',
#   'sold',
#   'them',
#   'down',
#   'the',
#   'river',
#   'to',
#   'annihil'],
#  ['evildead', 'annihil', 'of', 'civil', ':'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   ':'],
#  ['annihil', 'quarterstaff', 'of', 'annihil'],
#  ['world', 'annihil', 'vs', 'self', 'transform', ':'],
#  [':',
#   'starmad',
#   ':',
#   ':',
#   'stardat',
#   ':',
#   ':',
#   'planetari',
#   'annihil',
#   ':',
#   ':',
#   ':'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   's',
#   ':'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   's',
#   ':'],
#  ['can',
#   'you',
#   'pleas',
#   'sign',
#   'and',
#   'share',
#   'thi',
#   'petit',
#   'to',
#   'save',
#   'wild',
#   'hors',
#   'in',
#   'arizona',
#   ':'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   ':'],
#  ['pleas',
#   'check',
#   'into',
#   'salt',
#   'river',
#   'hors',
#   'help',
#   'stop',
#   'the',
#   'annihil',
#   'about',
#   'to',
#   'happen',
#   'without',
#   'more',
#   'signatureschang',
#   'org',
#   'thx'],
#  ['are', 'soul', 'punish', 'withåêannihil', '?', ':'],
#  ['not',
#   'to',
#   'mention',
#   'a',
#   'major',
#   'contributor',
#   'to',
#   'the',
#   'annihil',
#   'of',
#   'israel'],
#  ['we',
#   'need',
#   'help',
#   '!',
#   'hors',
#   'will',
#   'die',
#   '!',
#   'pleas',
#   'rt',
#   '&',
#   'amp',
#   'sign',
#   'petit',
#   '!',
#   'take',
#   'a',
#   'stand',
#   '&',
#   'amp',
#   'be',
#   'a',
#   'voic',
#   'for',
#   'them',
#   '!',
#   'gilbert',
#   's',
#   ':'],
#  ['i',
#   'reject',
#   'the',
#   'law',
#   'of',
#   'the',
#   'misguid',
#   'fals',
#   'prophet',
#   'imprison',
#   'nation',
#   'fuel',
#   'self',
#   'annihil'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   's',
#   ':'],
#  ['the',
#   'annihil',
#   'of',
#   'jeb',
#   'christi',
#   '&',
#   'amp',
#   'kasich',
#   'is',
#   'less',
#   'than',
#   'hour',
#   'away',
#   'pleas',
#   'god',
#   'allow',
#   'me',
#   'at',
#   'least',
#   'one',
#   'more',
#   'full',
#   'day'],
#  ['we',
#   'need',
#   'helphors',
#   'will',
#   'die',
#   '!',
#   'pleas',
#   'rt',
#   '&',
#   'amp',
#   'sign',
#   'petit',
#   '!',
#   'take',
#   'a',
#   'stand',
#   '&',
#   'amp',
#   'be',
#   'a',
#   'voic',
#   'for',
#   'them',
#   '!',
#   'gilbert',
#   's',
#   ':'],
#  ['we',
#   'need',
#   'help',
#   '!',
#   'hors',
#   'will',
#   'die',
#   '!',
#   'pleas',
#   'rt',
#   '&',
#   'amp',
#   'sign',
#   'petit',
#   '!',
#   'take',
#   'a',
#   'stand',
#   '&',
#   'amp',
#   'be',
#   'a',
#   'voic',
#   'for',
#   'them',
#   '!',
#   'gilbert',
#   's',
#   ':'],
#  ['hey',
#   'az',
#   ':',
#   'sign',
#   'thi',
#   'petit',
#   'to',
#   'save',
#   'the',
#   'wildhors',
#   '@',
#   'tantonationalforest',
#   '!',
#   'a',
#   'singalong',
#   'is',
#   'in',
#   'order',
#   ':',
#   ':'],
#  ['stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   '!',
#   ':'],
#  ['and',
#   'he',
#   "'s",
#   'the',
#   'current',
#   'nova',
#   'in',
#   'the',
#   'bookslast',
#   'i',
#   'checkedh',
#   'wa',
#   'tie',
#   'into',
#   'the',
#   'book',
#   'in',
#   'after',
#   'rider',
#   'die',
#   'dure',
#   'annihil'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   's',
#   ':'],
#  ['pleas', 'sign', '&', 'amp', 'rt', 'to', 'save', 'saltriverwildhors', ':'],
#  ['thank',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'dant',
#   ':',
#   ')',
#   'do',
#   'join',
#   'us',
#   'by',
#   'follow',
#   'the',
#   'zone',
#   'johnni'],
#  ['world', 'annihil', 'vs', 'self', 'transform', ':'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   's',
#   ':'],
#  ['us',
#   'nation',
#   'park',
#   'servic',
#   'tonto',
#   'nation',
#   'forest',
#   ':',
#   'stop',
#   'the',
#   'annihil',
#   'of',
#   'the',
#   'salt',
#   'river',
#   'wild',
#   'hors',
#   ':'],
#  ['i',
#   "'m",
#   'gon',
#   'na',
#   'fight',
#   'taylor',
#   'as',
#   'soon',
#   'as',
#   'i',
#   'get',
#   'there'],
#  ['ohh',
#   'no',
#   'fukurodani',
#   'did',
#   "n't",
#   'surviv',
#   'the',
#   'apocalyps',
#   'bokuto',
#   'feel',
#   'horribl',
#   'my',
#   'poor',
#   'boy',
#   'my',
#   'ppor',
#   'child'],
#  ['will', 'there', 'be', 'anoth', 'jocelyn', 'birthday', 'apocalyps'],
#  ['rt',
#   ':',
#   'janenelson',
#   ':',
#   'rt',
#   'stephenscifi',
#   ':',
#   'adapt',
#   'watch',
#   ':',
#   'charli',
#   'human',
#   "'s",
#   'apocalyps',
#   'now',
#   'now',
#   'option',
#   'for',
#   'film',
#   'sciencefict'],
#  ['apocalyps', 'pleas'],
#  ['anoth',
#   'hour',
#   '!',
#   'it',
#   "'s",
#   'august',
#   'at',
#   ':',
#   'pm',
#   'here',
#   "'s",
#   'red',
#   'rover',
#   'zombi',
#   'apocalyps',
#   '!',
#   ':'],
#  ['i',
#   'feel',
#   'like',
#   'me',
#   'do',
#   'a',
#   'pullup',
#   'is',
#   'one',
#   'of',
#   'the',
#   'stage',
#   'of',
#   'the',
#   'apocalyps'],
#  ['she',
#   "'s",
#   'kinda',
#   'hot',
#   'play',
#   'on',
#   'the',
#   'radio',
#   'today',
#   'what',
#   "'s",
#   'next',
#   '?',
#   'diseas',
#   'to',
#   'all',
#   '?',
#   'the',
#   'apocalyps',
#   'ha',
#   'start',
#   'everyon',
#   'be',
#   'care'],
#  ['but', 'if', 'it', "'s", 'the', 'apocalyps', 'lol', 'gf', 'm'],
#  ['i',
#   'know',
#   'it',
#   "'s",
#   'a',
#   'question',
#   'of',
#   'interpret',
#   'but',
#   'thi',
#   'is',
#   'a',
#   'sign',
#   'of',
#   'the',
#   'apocalyps',
#   'i',
#   'call',
#   'it',
#   's',
#   ':'],
#  ['juli',
#   'r',
#   'is',
#   'the',
#   'apocalyps',
#   'version',
#   'of',
#   'romeo',
#   'juliet',
#   'warmbodi'],
#  ['the', 'apocalyps', 'is', 'upon', 'us'],
#  ['rt',
#   ':',
#   'fittscott',
#   ':',
#   'minecraft',
#   'night',
#   'lucki',
#   'block',
#   'mod',
#   '(',
#   'bob',
#   'apocalyps',
#   'wither',
#   '&',
#   'amp',
#   'more',
#   '!',
#   ')',
#   'mod',
#   'showcas',
#   'popularmmo',
#   ':',
#   ':'],
#  ['and', 'so', 'it', 'begin', 'day', 'one', 'of', 'the', 'snow', 'apocalyps'],
#  ['rt',
#   ':',
#   'ourmothermari',
#   ':',
#   'short',
#   'read',
#   'apocalyps',
#   ':',
#   'in',
#   'the',
#   'spirit',
#   'the',
#   'angel',
#   'took',
#   'me',
#   'to',
#   'the',
#   'top',
#   'of',
#   'an',
#   'enorm',
#   'high',
#   'mountain',
#   'and'],
#  ['candylit',
#   ':',
#   'imagin',
#   'sarumi',
#   'in',
#   'a',
#   'zombi',
#   'apocalyps',
#   'fight',
#   'back',
#   'to',
#   'back',
#   'heart',
#   'to',
#   'heart',
#   'convers',
#   'over',
#   'the',
#   ':'],
#  ['rt', ':', 'zonewolf', ':', 'i', 'like', 'a', 'youtub', 'video', ':'],
#  ['and',
#   'that',
#   "'s",
#   'becaus',
#   'on',
#   'my',
#   'planet',
#   'it',
#   "'s",
#   'the',
#   'lone',
#   'audienc',
#   'of',
#   'the',
#   'apocalyps',
#   '!'],
#  ['dad',
#   'bought',
#   'a',
#   'dvd',
#   'that',
#   'look',
#   'like',
#   'a',
#   'scienc',
#   'doc',
#   'on',
#   'the',
#   'front',
#   'but',
#   'i',
#   'read',
#   'the',
#   'back',
#   'and',
#   'it',
#   "'s",
#   'actual',
#   'about',
#   'the',
#   'impend',
#   'biblic',
#   'apocalyps'],
#  ['it',
#   'is',
#   'inde',
#   'if',
#   'the',
#   'apocalyps',
#   'come',
#   'thi',
#   'week',
#   'i',
#   'know',
#   'where',
#   'i',
#   "'ll",
#   'be',
#   ':',
#   ')'],
#  ['go',
#   'look',
#   'at',
#   'grizzli',
#   'peak',
#   'right',
#   'now',
#   'it',
#   'look',
#   'like',
#   'the',
#   'begin',
#   'of',
#   'an',
#   'dystopian',
#   'apocalyps',
#   'movi'],
#  ['my',
#   'niec',
#   'just',
#   'ask',
#   'me',
#   "'would",
#   'you',
#   'be',
#   'scare',
#   'if',
#   'there',
#   'wa',
#   'an',
#   'apocalyps',
#   'here',
#   '?',
#   "'",
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['there',
#   "'s",
#   'a',
#   'storm',
#   'over',
#   'cairo',
#   'in',
#   'the',
#   'latest',
#   "'xmen",
#   'apocalyps',
#   "'",
#   'set',
#   'photo',
#   's',
#   ':'],
#  ['minecraft',
#   'night',
#   'lucki',
#   'block',
#   'mod',
#   '(',
#   'bob',
#   'apocalyps',
#   'wither',
#   '&',
#   'amp',
#   'more',
#   '!',
#   ')',
#   'mod',
#   'showcas',
#   'popularmmo',
#   ':',
#   ':'],
#  ['shot',
#   'through',
#   'the',
#   'heart',
#   'xv',
#   ':',
#   'you',
#   'are',
#   'go',
#   'to',
#   'total',
#   'give',
#   'love',
#   'a',
#   'bad',
#   'name',
#   'with',
#   'thi',
#   'heart',
#   'pierc',
#   ':'],
#  ['rt',
#   ':',
#   'geekapocalyps',
#   ':',
#   'pm',
#   'gmt',
#   ':',
#   'hess',
#   'play',
#   'dark',
#   'soul',
#   'day',
#   ':',
#   ':'],
#  ['i',
#   'know',
#   'where',
#   'to',
#   'go',
#   'when',
#   'the',
#   'zombi',
#   'take',
#   'over',
#   '!',
#   '!',
#   ':'],
#  ['the',
#   'latest',
#   'from',
#   'reveal',
#   'storm',
#   'is',
#   'a',
#   'queen',
#   'in',
#   'apocalyps',
#   ':'],
#  ['shadow', 'box', 'the', 'apocalyps'],
#  ['short',
#   'read',
#   'apocalyps',
#   ':',
#   'in',
#   'the',
#   'spirit',
#   'the',
#   'angel',
#   'took',
#   'me',
#   'to',
#   'the',
#   'top',
#   'of',
#   'an',
#   'enorm',
#   'high',
#   'mountain',
#   'and',
#   ':'],
#  ['enjoy',
#   'liveact',
#   'attack',
#   'on',
#   'titan',
#   'but',
#   'everi',
#   'time',
#   'i',
#   'see',
#   'poster',
#   'i',
#   "'m",
#   'remind',
#   'how',
#   'freshli',
#   'clean',
#   'and',
#   'coif',
#   'everyon',
#   'is',
#   'in',
#   'the',
#   'apocalyps'],
#  ['i', 'like', 'a', 'video', ':'],
#  ['pbban',
#   '(',
#   'temporari',
#   ':',
#   ')',
#   'avysss',
#   '@',
#   "'armageddon",
#   'do',
#   'not',
#   'kill',
#   'flag',
#   'onli',
#   'fast',
#   'xp',
#   "'",
#   'for',
#   'reason'],
#  ['pbban',
#   '(',
#   'temporari',
#   ':',
#   ')',
#   'russaki',
#   '@',
#   "'armageddon",
#   'do',
#   'not',
#   'kill',
#   'flag',
#   'onli',
#   'fast',
#   'xp',
#   "'",
#   'for',
#   'reason'],
#  ['(',
#   '(',
#   'offici',
#   'vid',
#   ')',
#   ')',
#   'doublecup',
#   '&',
#   'gt',
#   '&',
#   'gt',
#   's',
#   ':'],
#  ['ouvindo', 'peac', 'love', '&', 'amp', 'armageddon'],
#  ['best', 'movi', 'you', "'ve", 'ever', 'seen', '?', 'armageddon', ':'],
#  ['bed',
#   'time',
#   'do',
#   "n't",
#   'wake',
#   'me',
#   'up',
#   'unless',
#   'revolut',
#   'or',
#   'armageddon',
#   'start'],
#  ['red',
#   'faction',
#   ':',
#   'armageddon',
#   '(',
#   'microsoft',
#   'xbox',
#   ')',
#   'full',
#   'read',
#   'by',
#   'ebay',
#   ':'],
#  ['you',
#   'alreadi',
#   'know',
#   'how',
#   'thi',
#   'shit',
#   'goe',
#   'world',
#   'seri',
#   'or',
#   'armageddon'],
#  ['rt',
#   ':',
#   'love',
#   'truelov',
#   'romanc',
#   'lith',
#   'voodoo',
#   'seduct',
#   'astrolog',
#   'rtrrt',
#   'lotz',
#   'apocalyps',
#   'armageddon',
#   'pla'],
#  ['im',
#   'gon',
#   'na',
#   'beat',
#   'armageddon',
#   'as',
#   'hsu',
#   'hao',
#   '?',
#   '?',
#   '?',
#   '?',
#   'just',
#   'got',
#   'a',
#   'flawless',
#   'on',
#   'my',
#   'first',
#   'tri'],
#  ['ben',
#   'afflecki',
#   'know',
#   'there',
#   "'s",
#   'a',
#   'wifekid',
#   'and',
#   'other',
#   'girl',
#   'but',
#   'i',
#   'ca',
#   "n't",
#   'help',
#   'it',
#   'i',
#   "'ve",
#   'love',
#   'him',
#   'sinc',
#   'armageddon',
#   'eonlinechat'],
#  ["'if",
#   'i',
#   "'d",
#   'have',
#   'had',
#   'a',
#   'long',
#   'coat',
#   'to',
#   'hand',
#   'i',
#   "'d",
#   'have',
#   'worn',
#   'it',
#   'the',
#   'certainti',
#   'of',
#   'armageddon',
#   'bear',
#   'a',
#   'sens',
#   'of',
#   'occas',
#   "'"],
#  ['your',
#   'phone',
#   'is',
#   'spi',
#   'on',
#   'you',
#   '!',
#   'hidden',
#   'back',
#   'door',
#   'nsa',
#   'data',
#   'mine',
#   'softwar',
#   'the',
#   'financi',
#   'armageddon',
#   'blog',
#   ':'],
#  ['pbban',
#   '(',
#   'temporari',
#   ':',
#   ')',
#   'hyiderghost',
#   '@',
#   "'armageddon",
#   'do',
#   'not',
#   'kill',
#   'flag',
#   'onli',
#   'fast',
#   'xp',
#   "'",
#   'for',
#   'reason'],
#  ['rt',
#   ':',
#   'love',
#   'truelov',
#   'romanc',
#   'lith',
#   'voodoo',
#   'seduct',
#   'astrolog',
#   'rtrrt',
#   'lotz',
#   'apocalyps',
#   'armageddon',
#   'planet'],
#  ['pbban',
#   '(',
#   'temporari',
#   ':',
#   ')',
#   'fighterdena',
#   '@',
#   "'armageddon",
#   'do',
#   'not',
#   'kill',
#   'flag',
#   'onli',
#   'fast',
#   'xp',
#   "'",
#   'for',
#   'reason'],
#  ['photo',
#   ':',
#   'sketch',
#   'i',
#   'did',
#   'base',
#   'on',
#   'the',
#   'a',
#   'tast',
#   'of',
#   'armageddon',
#   'episod',
#   'of',
#   'startrek',
#   'to',
#   ':'],
#  ['armageddon', 's', ':'],
#  ['good',
#   'luck',
#   'to',
#   'the',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   'tomorrow',
#   'night',
#   'get',
#   'some',
#   'coeffici',
#   'point',
#   'plz',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['armageddon'],
#  ['you',
#   "'re",
#   'anoth',
#   'one',
#   'for',
#   'the',
#   'histori',
#   'book',
#   '!',
#   '(',
#   'thank',
#   'the',
#   'justic',
#   'depart',
#   '!',
#   ')',
#   'and',
#   'by',
#   'the',
#   'way',
#   'i',
#   'have',
#   "n't",
#   'paid',
#   'incom',
#   'tax',
#   'in',
#   'yr'],
#  ['vladimir',
#   'putin',
#   'issu',
#   'major',
#   'warn',
#   'but',
#   'is',
#   'it',
#   'too',
#   'late',
#   'to',
#   'escap',
#   'armageddon',
#   '?',
#   ':'],
#  ['god',
#   "'s",
#   'kingdom',
#   '(',
#   'heavenli',
#   "gov't",
#   ')',
#   'will',
#   'rule',
#   'over',
#   'all',
#   'peopl',
#   'on',
#   'the',
#   'earth',
#   'after',
#   'armageddon',
#   ':'],
#  ['l',
#   'b',
#   'entertain',
#   'lot',
#   'of',
#   'brucewilli',
#   'movi',
#   'dvd',
#   'die',
#   'hard',
#   'monkey',
#   'armageddon',
#   'sixth',
#   'ebay',
#   'auction',
#   ':'],
#  ['let'],
#  ['my',
#   'niec',
#   'is',
#   'gain',
#   'the',
#   'abil',
#   'to',
#   'stand',
#   'i',
#   "'m",
#   'get',
#   'prepar',
#   'for',
#   'toddler',
#   'apocalyps',
#   'armageddon'],
#  ['check',
#   'out',
#   'prepper',
#   'doomsday',
#   'must',
#   'have',
#   'librari',
#   'collect',
#   'on',
#   'cd',
#   'shtf',
#   'preppertalk',
#   'surviv',
#   'a',
#   'prepper',
#   ':'],
#  ['again',
#   '?',
#   '?',
#   'eep',
#   '!',
#   'thought',
#   'of',
#   'you',
#   'yesterday',
#   'when',
#   'i',
#   'saw',
#   'that',
#   'hella',
#   'scari',
#   'hail',
#   'armageddon',
#   '?'],
#  ['so',
#   'the',
#   'ahamedi',
#   'think',
#   'the',
#   'messiah',
#   'had',
#   'alreadi',
#   'come',
#   'year',
#   'ago',
#   '?',
#   'where',
#   'is',
#   'armageddon',
#   '?',
#   'where',
#   'is',
#   'the',
#   'dajaal',
#   '?',
#   'where',
#   'is',
#   'gog',
#   '&',
#   'amp',
#   'magog',
#   '?',
#   '!'],
#  ['sadli',
#   'how',
#   'window',
#   'reveal',
#   'microsoft',
#   "'s",
#   'ethic',
#   'armageddon',
#   ':'],
#  ['armageddon', 'avert', 'by', 'el', 'patron', 'ultimalucha'],
#  ['if',
#   'you',
#   'have',
#   'the',
#   'time',
#   '(',
#   'hour',
#   '?',
#   '?',
#   ')',
#   'the',
#   'latest',
#   'seri',
#   'about',
#   'ww',
#   'blueprint',
#   'for',
#   'armageddon',
#   'is',
#   'extrem',
#   'impress'],
#  ['european', 'fitba', 'till', 'christma', 'armageddon'],
#  ['christian',
#   'unit',
#   'for',
#   'israel',
#   '(',
#   'cufi',
#   ')',
#   ':',
#   'jew',
#   'should',
#   'convert',
#   'soon',
#   'or',
#   'die',
#   'by',
#   'armageddon',
#   's',
#   ':'],
#  ['(',
#   'offici',
#   'vid',
#   ')',
#   '&',
#   'gt',
#   'doublecup',
#   '&',
#   'gt',
#   '&',
#   'gt',
#   's',
#   ':'],
#  ['tomorrow',
#   'is',
#   'the',
#   'day',
#   'we',
#   'start',
#   'armageddon',
#   'preseasonworkout',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['lee', 'doe', 'comedi', ':'],
#  ['chart',
#   'prove',
#   'financi',
#   'crisi',
#   'part',
#   'ha',
#   'begun',
#   '!',
#   ':',
#   'the',
#   'financi',
#   'armageddon',
#   'econom',
#   'collaps',
#   'blog',
#   'track',
#   'tren',
#   ':'],
#  ['paul', 'craig', 'robert'],
#  ['you',
#   "'re",
#   'on',
#   'stage',
#   'now',
#   '!',
#   'right',
#   'under',
#   'the',
#   'light',
#   '!',
#   'is',
#   "n't",
#   'it',
#   'funni',
#   '?',
#   '!',
#   'where',
#   'do',
#   'you',
#   'get',
#   'the',
#   'goofbal',
#   'with',
#   'which',
#   'you',
#   'staff',
#   'your',
#   'pd',
#   '?'],
#  ['offici', 'vid', 'thereal', '&', 'gt', '&', 'gt', '&', 'gt', 's', ':'],
#  ['well',
#   'done',
#   'celtic',
#   'finger',
#   'cross',
#   'for',
#   'aberdeen',
#   'tomorrow',
#   'night',
#   '!',
#   'armageddon',
#   'eh',
#   '?',
#   '?'],
#  ['beyonc', 'is', 'my', 'pick', 'for', ':'],
#  ['one', 'direct', 'is', 'my', 'pick', 'for', ':'],
#  ['second', 'of', 'summer', 'is', 'my', 'pick', 'for', ':'],
#  ['beyonc', 'is', 'my', 'pick', 'for', ':'],
#  ['beyonc', 'is', 'my', 'pick', 'for', ':'],
#  ['one', 'direct', 'is', 'my', 'pick', 'for', ':'],
#  ['see',
#   'that',
#   'armi',
#   'of',
#   'whitewalk',
#   'wa',
#   'the',
#   'veri',
#   'first',
#   'thing',
#   'that',
#   'ha',
#   'slightli',
#   'intrigu',
#   'me',
#   'on',
#   'got',
#   'so',
#   'far'],
#  ['build',
#   'your',
#   'own',
#   'kingdom',
#   'and',
#   'lead',
#   'your',
#   'armi',
#   'to',
#   'victori',
#   '!',
#   's',
#   ':',
#   'youtu',
#   'start',
#   'g',
#   'thi',
#   'friend',
#   'code',
#   ':',
#   'lzktjnox',
#   ':'],
#  ['salvat',
#   'armi',
#   'host',
#   'ralli',
#   'to',
#   'reconnect',
#   'father',
#   'with',
#   'children',
#   ':',
#   'the',
#   'salvat',
#   'armi',
#   'is',
#   'host',
#   'a',
#   'back',
#   'to',
#   'school',
#   'ralli'],
#  ['vote',
#   'for',
#   'direction',
#   'vs',
#   'queen',
#   'in',
#   'the',
#   'th',
#   'round',
#   'of',
#   'the',
#   'fanarmyfaceoff',
#   ':'],
#  ['but',
#   'if',
#   'you',
#   'build',
#   'an',
#   'armi',
#   'of',
#   'dog',
#   'and',
#   'their',
#   'leader',
#   'is',
#   'a',
#   'lion',
#   'all',
#   'dog',
#   'will',
#   'fight',
#   'like',
#   'a',
#   'lion'],
#  ["'show", 'me', 'a', 'hero', "'", ':', 'tv', 'review', ':'],
#  ['one', 'direct', 'is', 'my', 'pick', 'for', ':'],
#  ['infantri',
#   'men',
#   'lume',
#   'dial',
#   'armi',
#   'analog',
#   'quartz',
#   'wrist',
#   'watch',
#   'sport',
#   'blue',
#   'nylon',
#   'fabric',
#   'full',
#   'rea'],
#  ['one', 'direct', 'is', 'my', 'pick', 'for', ':'],
#  ['victorinox',
#   'swiss',
#   'armi',
#   'date',
#   'women',
#   "'s",
#   'rubber',
#   'mop',
#   'watch',
#   ':'],
#  [':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
# ...
#  ['i',
#   'tri',
#   'eye',
#   'akam',
#   'ga',
#   'kill',
#   'and',
#   'tokyo',
#   'ghoul',
#   'all',
#   'damn',
#   'bloodi',
#   'i',
#   'dont',
#   'dare',
#   'watch',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['now',
#   'suck',
#   'it',
#   'up',
#   'becaus',
#   'that',
#   "'s",
#   'all',
#   'you',
#   "'re",
#   'bloodi',
#   'get',
#   'out',
#   'of',
#   'me',
#   'by',
#   'mean',
#   'of',
#   'amend'],
#  ['you',
#   'call',
#   'them',
#   'weekend',
#   'i',
#   'call',
#   'them',
#   'bloodi',
#   'mari',
#   'time',
#   'thi',
#   'summer',
#   "'s",
#   'been',
#   'full',
#   'of',
#   'them',
#   'my',
#   'new'],
#  ['bloodi',
#   'hell',
#   'what',
#   'a',
#   'day',
#   'i',
#   'have',
#   "n't",
#   'even',
#   'realli',
#   'done',
#   'anyth',
#   'just',
#   'tire',
#   'of',
#   'everyth',
#   'thought',
#   'vaca',
#   'would',
#   'help',
#   'but',
#   'it',
#   'onli',
#   'did',
#   'so',
#   'much',
#   '='],
#  ['damn', 'bloodi', 'hot'],
#  ['it', "'s", 'bloodi', 'sexi', 'drool'],
#  ['you',
#   'know',
#   'how',
#   'they',
#   'say',
#   'the',
#   'side',
#   'effect',
#   'low',
#   '&',
#   'amp',
#   'realli',
#   'fast',
#   '?',
#   'son',
#   'the',
#   'product',
#   'wa',
#   'an',
#   'acn',
#   'cream',
#   'whi',
#   'of',
#   'the',
#   'side',
#   'effect',
#   'wa',
#   'bloodi',
#   'diarrhea',
#   '?'],
#  ['ronda',
#   'rousey',
#   'would',
#   'be',
#   "'close",
#   "'",
#   'to',
#   'make',
#   'floyd',
#   'mayweath',
#   "'s",
#   'money',
#   'in',
#   'fight',
#   'bloodi',
#   'elbow',
#   ':'],
#  ['i',
#   "'m",
#   'aw',
#   'at',
#   'paint',
#   'whi',
#   'did',
#   'i',
#   'agre',
#   'to',
#   'do',
#   'an',
#   'a',
#   'landscap',
#   'in',
#   'bloodi',
#   'oil',
#   'of',
#   'all',
#   'paint',
#   '?',
#   '?'],
#  ['all',
#   'i',
#   'need',
#   'in',
#   'thi',
#   'life',
#   'of',
#   'sin',
#   'is',
#   'just',
#   'me',
#   'and',
#   'my',
#   'girlfriend',
#   'down',
#   'to',
#   'ride',
#   'till',
#   'the',
#   'bloodi',
#   'end',
#   'just',
#   'me',
#   'and',
#   'my',
#   'girlfriend'],
#  ['i', 'think', 'it', 'is', 'well', 'it', "'s", 'bloodi', 'bark', 'now'],
#  ['eh',
#   'hello',
#   'cover',
#   'your',
#   'bloodi',
#   'thigh',
#   'your',
#   'bloodi',
#   'cleav'],
#  ['mega', 'bloodi', 'marvel'],
#  ['bloodi', 'mari', 'in', 'the', 'sink', 'beet', 'juic', ':'],
#  ['if',
#   'my',
#   'monti',
#   'python',
#   'is',
#   'up',
#   'to',
#   'date',
#   'as',
#   'bloodi',
#   'far',
#   'as',
#   'he',
#   'want',
#   'to',
#   'go'],
#  ['meet', 'the', 'bloodi', 'rs', ':'],
#  ['friday',
#   'suppos',
#   'to',
#   'be',
#   'a',
#   'happi',
#   'day',
#   'but',
#   'it',
#   "'s",
#   'a',
#   'bloodi',
#   'friday',
#   'hah',
#   'zzzz'],
#  ['i',
#   'should',
#   'bloodi',
#   'hope',
#   'so',
#   'she',
#   'said',
#   'fold',
#   'her',
#   'arm',
#   'sit',
#   'back',
#   'in',
#   'her',
#   'chair'],
#  ['wait',
#   'until',
#   'i',
#   'tell',
#   'my',
#   'colleg',
#   'friend',
#   'who',
#   'reaf',
#   'bloodi',
#   'mari',
#   'too',
#   'about',
#   'the',
#   'drama',
#   'cd'],
#  ["'",
#   'i',
#   'came',
#   'to',
#   'kill',
#   'indiansfor',
#   'fun',
#   "'",
#   ':',
#   'video',
#   'of',
#   'smirk',
#   'and',
#   'remorseless',
#   'pakistani',
#   'killer',
#   'show',
#   'him',
#   'boast',
#   ':'],
#  ['i',
#   "'ve",
#   'just',
#   'watch',
#   'episod',
#   'se',
#   'of',
#   'bloodi',
#   'monday',
#   '!',
#   ':'],
#  ['marlon',
#   'william',
#   '&',
#   'gt',
#   'elvi',
#   'presley',
#   '&',
#   'gt',
#   'marlon',
#   'william',
#   '&',
#   'gt',
#   'steel',
#   'panther',
#   'shuffl',
#   'mode',
#   'like',
#   'a',
#   'bloodi',
#   'legend'],
#  ['black',
#   'friday',
#   'turn',
#   'bloodi',
#   '(',
#   'would',
#   'rather',
#   'be',
#   'shop',
#   ')',
#   ':'],
#  ['someon',
#   'told',
#   'me',
#   'all',
#   'the',
#   'soccer',
#   'mom',
#   'are',
#   'get',
#   'thi',
#   'pic',
#   'blown',
#   'up',
#   'and',
#   'put',
#   'on',
#   'their',
#   'daughter',
#   "'s",
#   'bedroom',
#   'wall',
#   'not',
#   '!',
#   '!',
#   '!'],
#  ['and',
#   'i',
#   'sg',
#   'if',
#   'my',
#   'mention',
#   'get',
#   'blown',
#   'up',
#   'over',
#   'my',
#   'choic',
#   'i',
#   'will',
#   'deactiv',
#   'and',
#   'leav',
#   'for',
#   'good',
#   'respect',
#   'my',
#   'choic'],
#  ['wow',
#   'just',
#   'wow',
#   '!',
#   'if',
#   'ani',
#   'other',
#   'club',
#   'had',
#   'blown',
#   'all',
#   'that',
#   'money',
#   'and',
#   'fuck',
#   'up',
#   'a',
#   'player',
#   'like',
#   'that',
#   'they',
#   "'d",
#   'be',
#   'pillori',
#   '!'],
#  ['damn', 'greink', 'got', 'blown', 'up', 'in', 'that', 'first', 'inning'],
#  ['woke', 'up', 'so', 'blown', 'lol'],
#  ['aunt', 'marg', 'you', "'re", 'blown', 'up', 'ehek'],
#  ['yeah',
#   'it',
#   'not',
#   'worth',
#   'it',
#   'bc',
#   'he',
#   'alreadi',
#   'ha',
#   'so',
#   'mani',
#   'spammer',
#   '&',
#   'amp',
#   'hi',
#   'twitter',
#   'is',
#   'probabl',
#   'blown',
#   'up',
#   'everi',
#   'second'],
#  ['white',
#   'famili',
#   '(',
#   'supposedli',
#   'repres',
#   'america',
#   "'s",
#   'great',
#   'valu',
#   ')',
#   'get',
#   'blown',
#   'up',
#   'in',
#   'a',
#   'horribl',
#   'cgi',
#   'nuclear',
#   'strike',
#   'lmfaoooo',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['man',
#   'whi',
#   'ha',
#   "n't",
#   'blown',
#   'up',
#   '?',
#   'he',
#   "'s",
#   'still',
#   'underground'],
#  ['and',
#   'my',
#   'mention',
#   'are',
#   'blown',
#   'up',
#   'for',
#   'what',
#   '?',
#   '?',
#   '?',
#   'wtf'],
#  ['on',
#   'thisdayinhistori',
#   'in',
#   'confeder',
#   'ship',
#   'blown',
#   'up',
#   'by',
#   'crew',
#   'read',
#   'more',
#   ':'],
#  ['that',
#   'moment',
#   'when',
#   'ur',
#   'about',
#   'to',
#   'win',
#   'a',
#   'mini',
#   'uhc',
#   'and',
#   'than',
#   'get',
#   'blown',
#   'up',
#   'by',
#   'a',
#   'creeper',
#   'and',
#   'get',
#   'kick',
#   'for',
#   'fli',
#   'so',
#   'salti',
#   'rn',
#   '!',
#   '!',
#   '!',
#   '?',
#   '?'],
#  ['he',
#   'did',
#   'get',
#   'a',
#   "'bump",
#   "'",
#   'of',
#   'approv',
#   'which',
#   'is',
#   'probabl',
#   'whi',
#   'he',
#   "'s",
#   'blown',
#   'up',
#   ':'],
#  ["'if",
#   'a',
#   'truckload',
#   'of',
#   'soldier',
#   'will',
#   'be',
#   'blown',
#   'up',
#   'nobodi',
#   'panic',
#   'but',
#   'when',
#   'one',
#   'littl',
#   'lion',
#   'die',
#   'everyon',
#   'lose',
#   'their',
#   "mind'",
#   ':'],
#  ['hey',
#   'look',
#   '!',
#   '!',
#   '!',
#   'kash',
#   "'s",
#   'foundat',
#   'live',
#   'for',
#   'today',
#   'got',
#   'blown',
#   'up',
#   'on',
#   'peopl',
#   'magazin',
#   "'s",
#   'websit',
#   '!',
#   '!',
#   'todd',
#   'blake',
#   ':'],
#  ['got',
#   'it',
#   'last',
#   'month',
#   'when',
#   'i',
#   'went',
#   'into',
#   'the',
#   'ee',
#   'shop',
#   'glad',
#   'it',
#   'ha',
#   "n't",
#   'blown',
#   'up',
#   'yet',
#   ':'],
#  ['thi',
#   'is',
#   'the',
#   'first',
#   'time',
#   'a',
#   'tweet',
#   'ha',
#   'blown',
#   'up',
#   'almost',
#   'half',
#   'a',
#   'day',
#   'later',
#   're',
#   's',
#   ':'],
#  ["'we"],
#  ["'thank",
#   'again',
#   'for',
#   'let',
#   'me',
#   'stay',
#   'here',
#   'sinc',
#   'the',
#   'manor',
#   'wa',
#   'blown',
#   'up',
#   'anyway',
#   'how',
#   'are',
#   'you',
#   'do',
#   'buddi',
#   '?',
#   "'"],
#  ['loner',
#   'diari',
#   'the',
#   'pattern',
#   'on',
#   'the',
#   'sand',
#   'may',
#   'have',
#   'been',
#   'blown',
#   'away',
#   'the',
#   'photo',
#   'in',
#   'two',
#   'all',
#   'choke',
#   'up',
#   'in',
#   'flame',
#   ':'],
#  ['even',
#   'though',
#   'bsg',
#   'had',
#   'been',
#   'suffici',
#   'hype',
#   'up',
#   'for',
#   'me',
#   'in',
#   'all',
#   'the',
#   'year',
#   'i',
#   'somehow',
#   'delay',
#   'watch',
#   'it',
#   'i',
#   'wa',
#   'utterli',
#   'utterli',
#   'blown',
#   'away'],
#  ['vanessa',
#   "'s",
#   'game',
#   'ha',
#   'offici',
#   'blown',
#   'up',
#   'ladi',
#   'and',
#   'gentlementh',
#   'real',
#   'show',
#   'is',
#   'about',
#   'to',
#   'begin',
#   'bb'],
#  ['guarante',
#   'been',
#   'bitten',
#   'by',
#   'some',
#   'mutant',
#   'mosquito',
#   'my',
#   'ankl',
#   'ha',
#   'blown',
#   'up',
#   'littl',
#   'cunt'],
#  ['thing',
#   'you',
#   'can',
#   'pick',
#   'up',
#   'from',
#   'tozlet',
#   'seat',
#   ':',
#   'butt',
#   'leprosi',
#   'fullblown',
#   'jerkfac',
#   'syndrom',
#   'a',
#   'later',
#   'lisp',
#   '&',
#   'amp',
#   'toilet',
#   'ricket'],
#  ['my',
#   'ig',
#   'is',
#   'be',
#   'blown',
#   'up',
#   'just',
#   'with',
#   'hacker',
#   'i',
#   'need',
#   'it',
#   'to',
#   'stop',
#   'givebackkalinwhiteaccount'],
#  ['whoever',
#   'is',
#   'direct',
#   'these',
#   'video',
#   'need',
#   'to',
#   'grab',
#   'up',
#   'nicki',
#   'minaj',
#   'or',
#   'someon',
#   'with',
#   'us',
#   'recognit',
#   'so',
#   'mind',
#   'can',
#   'be',
#   'blown'],
#  ['last',
#   'week',
#   'want',
#   'the',
#   'th',
#   'sens',
#   'to',
#   'get',
#   'blown',
#   'up',
#   'so',
#   'far',
#   'so',
#   'good',
#   'jame',
#   'could',
#   'win',
#   'but',
#   'he',
#   "'s",
#   'a',
#   'huge',
#   'target',
#   'and',
#   'will',
#   'be',
#   'gone',
#   'soon'],
#  ['more', 'like', 'blown', 'up', 'amirit'],
#  ['my', 'dog'],
#  ['turn', 'on', 'espn', 'and', 'get', 'blown', 'up'],
#  ['went',
#   'down',
#   'i',
#   'wa',
#   'beaten',
#   'and',
#   'blown',
#   'up',
#   'then',
#   'next',
#   'thing',
#   'i',
#   'know',
#   'ra',
#   'al',
#   'ghul',
#   'brought',
#   'me',
#   'back',
#   'to',
#   'life',
#   'and',
#   'i',
#   'escap',
#   'and',
#   'for',
#   'a'],
#  ['leo',
#   'ass',
#   'just',
#   'got',
#   'metaphor',
#   'blown',
#   'up',
#   'again',
#   'piperwearsthep',
#   'charm'],
#  ['glononium',
#   'c',
#   'also',
#   'help',
#   'with',
#   'be',
#   'blown',
#   'up',
#   'while',
#   'bash',
#   'a',
#   'bottl',
#   'of',
#   'nitroglycerin',
#   'against',
#   'a',
#   'book'],
#  ['new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'bodi',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purs',
#   'full',
#   're'],
#  ['new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'bodi',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purs',
#   'full',
#   're'],
#  ['if',
#   'you',
#   'have',
#   'a',
#   'son',
#   'or',
#   'a',
#   'daughter',
#   'would',
#   'you',
#   'like',
#   'to',
#   'see',
#   'them',
#   'go',
#   'to',
#   'a',
#   'war',
#   'with',
#   'iran',
#   'and',
#   'come',
#   'back',
#   'in',
#   'a',
#   'bodi',
#   'bag',
#   '?',
#   'let',
#   'the',
#   'republican',
#   'know'],
#  ['ditto',
#   'but',
#   'it',
#   'all',
#   'we',
#   'had',
#   'and',
#   'the',
#   'way',
#   'i',
#   'feel',
#   'if',
#   'i',
#   'drank',
#   'vodka',
#   'over',
#   'ice',
#   'they',
#   'would',
#   'have',
#   'to',
#   'bodi',
#   'bag',
#   'me'],
#  ['handbag',
#   'genuin',
#   'mulberri',
#   'antoni',
#   'cross',
#   'bodi',
#   'messeng',
#   'bag',
#   'dark',
#   'oak',
#   'soft',
#   'buffalo',
#   'leather',
#   ':',
#   'å£end',
#   'date',
#   ':',
#   'w',
#   ':'],
#  ['loui',
#   'vuitton',
#   'monogram',
#   'sophi',
#   'limit',
#   'edit',
#   'clutch',
#   'cross',
#   'bodi',
#   'bag',
#   'full',
#   'read',
#   'by',
#   'ebay',
#   ':'],
#  ['loui',
#   'vuitton',
#   'monogram',
#   'sophi',
#   'limit',
#   'edit',
#   'clutch',
#   'cross',
#   'bodi',
#   'bag',
#   'full',
#   'read',
#   'by',
#   'ebay',
#   ':'],
#  ['loui',
#   'vuitton',
#   'cultsierr',
#   'monogram',
#   'shoulder',
#   'bag',
#   'cross',
#   'bodi',
#   'bag',
#   ':'],
#  ['check',
#   'out',
#   'ameribag',
#   'healthi',
#   'back',
#   'bag',
#   'shoulder',
#   'cross',
#   'bodi',
#   'backpack',
#   'khaki',
#   'tan',
#   'beig',
#   'nylon',
#   ':'],
#  ['photo',
#   ':',
#   'bath',
#   '&',
#   'amp',
#   'bodi',
#   'work',
#   'cosmet',
#   'bag',
#   'in',
#   'periwinkl',
#   'blue',
#   'with',
#   'copper',
#   'pipe',
#   'along',
#   'the',
#   'top',
#   'and',
#   'four',
#   'corner',
#   ':'],
#  ['new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'bodi',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purs',
#   'full',
#   're'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'bodi',
#   'bag',
#   'hip',
#   'a',
#   'word',
#   'skirt',
#   'blue',
#   ':'],
#  ['}',
#   'new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   ':'],
#  ['bruh',
#   'you',
#   'wan',
#   'na',
#   'fight',
#   'i',
#   "'m",
#   'down',
#   'meet',
#   'me',
#   'in',
#   'the',
#   'cage',
#   'bro',
#   'better',
#   'find',
#   'out',
#   'who',
#   'you',
#   "'re",
#   'deal',
#   'with',
#   'befor',
#   'you',
#   'end',
#   'up',
#   'in',
#   'a',
#   'bodi',
#   'bag'],
#  ['new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   'full',
#   'read'],
#  ['auth',
#   'loui',
#   'vuitton',
#   'brown',
#   'saumur',
#   'cross',
#   'bodi',
#   'shoulder',
#   'bag',
#   'monogram',
#   'full',
#   'read'],
#  ['check',
#   'out',
#   'vintag',
#   'longaberg',
#   'floral',
#   'fabric',
#   'shoulder',
#   'cross',
#   'bodi',
#   'bag',
#   'brown',
#   'leather',
#   'strap',
#   ':'],
#  ['?',
#   '?',
#   'new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   ':'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'bodi',
#   'bag',
#   'hip',
#   'a',
#   'word',
#   'skirt',
#   'blue',
#   ':'],
#  ['?',
#   'new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   ':'],
#  ['loui',
#   'vuitton',
#   'monogram',
#   'sophi',
#   'limit',
#   'edit',
#   'clutch',
#   'cross',
#   'bodi',
#   'bag',
#   'full',
#   'read',
#   'by',
#   'ebay',
#   ':'],
#  ['new',
#   'women',
#   'handbag',
#   'faux',
#   'leather',
#   'ladi',
#   'shoulder',
#   'tote',
#   'cross',
#   'bodi',
#   'bag',
#   'larg',
#   'satchel',
#   'full',
#   're'],
#  ['?',
#   '?',
#   'new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   ':'],
#  ['one',
#   'day',
#   'thi',
#   'heart',
#   'gone',
#   'get',
#   'me',
#   'zip',
#   'up',
#   'in',
#   'a',
#   'bodi',
#   'bag'],
#  ['handbag', 'fashion', 'style', ':'],
#  ['å',
#   '?',
#   'new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   ':'],
#  ['handbag', 'fashion', 'style', ':', '$', '(', 'bid', ')'],
#  ['genuin',
#   'leather',
#   'man',
#   'bag',
#   'messeng',
#   'fit',
#   'ipad',
#   'mini',
#   'tablet',
#   'case',
#   'cross',
#   'bodi',
#   'air',
#   'jp',
#   'full',
#   'rea'],
#  ['loui',
#   'vuitton',
#   'monogram',
#   'sophi',
#   'limit',
#   'edit',
#   'clutch',
#   'cross',
#   'bodi',
#   'bag',
#   'full',
#   'read',
#   'by',
#   'ebay',
#   ':'],
#  ['?',
#   '?',
#   'new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   ':'],
#  ['nuu',
#   'that',
#   'fam',
#   '?',
#   '?',
#   'fwt',
#   'i',
#   "'m",
#   'leav',
#   'you',
#   'in',
#   'a',
#   'bodi',
#   'bag',
#   '?',
#   '?'],
#  ['new',
#   'ladi',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purs',
#   'cross',
#   'bodi',
#   'bag',
#   'women',
#   'full',
#   'read'],
#  ['no',
#   'i',
#   "'m",
#   'not',
#   'i',
#   "'m",
#   'say',
#   'that',
#   'they',
#   "'re",
#   'lucki',
#   'they',
#   'can',
#   'go',
#   'home',
#   'to',
#   'their',
#   'famili',
#   'not',
#   'put',
#   'in',
#   'a',
#   'bodi',
#   'bag'],
#  ['oh',
#   'i',
#   "'m",
#   'not',
#   'bag',
#   'her',
#   'at',
#   'all',
#   '!',
#   'her',
#   'bodi',
#   'be',
#   'bangin',
#   "'",
#   'i',
#   "'m",
#   'say',
#   'she',
#   "'s",
#   'go',
#   'to',
#   'get',
#   'the',
#   'rose'],
#  ['who',
#   'is',
#   'bag',
#   'her',
#   'bodi',
#   '?',
#   'she',
#   "'s",
#   'smoke',
#   'hot',
#   '?',
#   '?'],
#  ['drake', 'is', 'realli', 'bodi', 'bag', 'meek'],
#  ['drake',
#   'kill',
#   'thi',
#   'dude',
#   'and',
#   'tea',
#   'bag',
#   'the',
#   'dead',
#   'bodi',
#   'at',
#   'thi',
#   'point'],
#  ['is',
#   'w',
#   '(',
#   'rec',
#   ')',
#   'k',
#   'leagu',
#   'ball',
#   'is',
#   'olymp',
#   'level',
#   'bodi',
#   'bag',
#   'him',
#   'like',
#   'hi',
#   'career',
#   'wa',
#   'noth',
#   'trollingtilmeekdiss'],
#  ['idgaf',
#   'who',
#   'tough',
#   'or',
#   'who',
#   'from',
#   'canada',
#   'and',
#   'who',
#   'from',
#   'north',
#   'philli',
#   'meek',
#   'been',
#   'act',
#   'like',
#   'a',
#   'bitch',
#   '&',
#   'amp',
#   'drake',
#   'been',
#   'bodi',
#   'bag',
#   'hi',
#   'ass',
#   'on',
#   'track'],
#  ['bodi', 'bag', 'mf'],
#  ['i', 'skim', 'through', 'twitter', 'and', 'miss', 'thi', 'bodi', 'bag'],
#  ['g', ':', 's', ':'],
#  ['straight', 'bodi', 'bag'],
#  ['bodi', 'bag', 'bitch', '?', '?', '?', '?', ':'],
#  ['no',
#   'better',
#   'feel',
#   'than',
#   'see',
#   'and',
#   'be',
#   'on',
#   'stage',
#   'with',
#   'my',
#   'day',
#   'one',
#   'year',
#   'friendship',
#   'and',
#   'we',
#   'still',
#   'bodi',
#   'bag',
#   'mic',
#   'togeth'],
#  ['mophem',
#   'and',
#   'bigstar',
#   'johnson',
#   'are',
#   'a',
#   'problem',
#   'in',
#   'thi',
#   'game',
#   'bodi',
#   'bag',
#   'nigga',
#   'vuzuhustl'],
#  ['i',
#   'wa',
#   'bodi',
#   'bag',
#   'on',
#   'the',
#   '?',
#   '?',
#   '?',
#   '?',
#   'todaygot',
#   'to',
#   'post',
#   'my',
#   'score',
#   ':'],
#  ['then',
#   'let',
#   'the',
#   'bag',
#   'bodi',
#   "'s",
#   'begin',
#   'lol',
#   '?',
#   '?',
#   '?',
#   '?',
#   'i',
#   'ai',
#   "n't",
#   'cuf',
#   'yet',
#   'so',
#   'it',
#   'should',
#   "n't",
#   'be',
#   'that',
#   'bad',
#   '!',
#   '!'],
#  ...]

# %%
new_tokenized_train = []

for sent in toknized_train:
    temp = []
    for word in sent:
        if word not in punctuation and len(word) < 16 and len(word) > 1:
            temp.append(word)
            
    new_tokenized_train.append(temp)

# %%
clear_data = []

for item in new_tokenized_train:
    clear_data.append(' '.join(item))
    
data = pd.DataFrame({'text' : clear_data, 'labels' : train['target']})

# %%
data
# Out:
#                                                    text  labels
# 0     our deed are the reason of thi earthquak may a...       1
# 1                  forest fire near la rong sask canada       1
# 2     all resid ask to 'shelter in place are be noti...       1
# 3        peopl receiv wildfir evacu order in california       1
# 4     just got sent thi photo from rubi alaska as sm...       1
# ...                                                 ...     ...
# 7608  two giant crane hold bridg collaps into nearbi...       1
# 7609  the out of control wild fire in california eve...       1
# 7610                           utc km of volcano hawaii       1
# 7611  polic investig after an ebik collid with car i...       1
# 7612  the latest more home raze by northern californ...       1
#
# [7613 rows x 2 columns]

# %%
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

test['text'] = test['text'].apply(lambda x: re.sub(r'@[a-zA-Z_]+', '', x))
test['text'] = test['text'].apply(lambda x: re.sub('#', '', x))
test['text'] = test['text'].apply(lambda x: x.lower())
test['text'] = test['text'].apply(lambda x: re.sub(r'\d+', '', x))
test['text'] = test['text'].apply(lambda x: re.sub('http', '', x))
test['text'] = test['text'].apply(lambda x: re.sub('//t.co/.*', '', x))
test['text'] = test['text'].apply(lambda x: re.sub('/+', '', x))
test['text'] = test['text'].apply(lambda x: re.sub('[;.,–-]', '', x))
test['text'] = test['text'].apply(lambda x: re.sub('[.+]', '', x))
test['text'] = test['text'].apply(lambda x: re.sub(chr(0x89) + '.*', '', x))
test['text'] = test['text'].apply(lambda x: re.sub(r'\*+', '', x))
test['text'] = test['text'].apply(lambda x: re.sub(r'\|+', '', x))
test['text'] = test['text'].apply(lambda x: re.sub(r'_', '', x))
test['text'] = test['text'].apply(lambda x: re.sub(r'å¤', '', x))
test['text'] = test['text'].apply(lambda x: re.sub(r'ìü', '', x))

cleared_test = test['text'].copy()

o_toknized_test = pd.Series([tokenizer.tokenize(sent) for sent in cleared_test])

toknized_test = []

for item in o_toknized_test:
    temp = []
    for word in item:
        temp.append(stemmer.stem(word))

    toknized_test.append(temp)


new_tokenized_test = []

for sent in toknized_test:
    temp = []
    for word in sent:
        if word not in punctuation and len(word) < 16 and len(word) > 1:
            temp.append(word)

    new_tokenized_test.append(temp)

clear_data_test = []

for item in new_tokenized_test:
    clear_data_test.append(' '.join(item))

clear_data_test

# %%
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['labels'])

pipe = Pipeline([('vect', CountVectorizer(min_df = 3, stop_words=stop_words)),
                ('tfidf', TfidfTransformer()),
                ('clf', SVC(random_state=1))])

parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
             'tfidf__use_idf': (True, False),
             'clf__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}

grid_s = GridSearchCV(pipe, parameters, n_jobs=-1, verbose=1)

grid_s_fit = grid_s.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed:  1.2min finished

# %%
from sklearn.metrics import accuracy_score
predicted = grid_s_fit.predict(X_test)


accuracy_score(y_test, predicted)
# Out:
# 0.8040966386554622

# %%
from sklearn.linear_model import LogisticRegression

new_pipe = Pipeline([('vect', CountVectorizer(min_df = 3, stop_words=stop_words)),
                ('tfidf', TfidfTransformer()),
                ('NB', LogisticRegression())])

new_parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
             'tfidf__use_idf': (True, False),
             'NB__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}

new_grid_s = GridSearchCV(new_pipe, new_parameters, n_jobs=-1, verbose=1)

new_grid_s_fit = new_grid_s.fit(X_train, y_train)

new_predicted = new_grid_s_fit.predict(X_test)

accuracy_score(y_test, new_predicted)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed:    9.4s finished
# 0.803046218487395

# %%
data
# Out:
#                                                    text  labels
# 0     our deed are the reason of thi earthquak may a...       1
# 1                  forest fire near la rong sask canada       1
# 2     all resid ask to 'shelter in place are be noti...       1
# 3        peopl receiv wildfir evacu order in california       1
# 4     just got sent thi photo from rubi alaska as sm...       1
# ...                                                 ...     ...
# 7608  two giant crane hold bridg collaps into nearbi...       1
# 7609  the out of control wild fire in california eve...       1
# 7610                           utc km of volcano hawaii       1
# 7611  polic investig after an ebik collid with car i...       1
# 7612  the latest more home raze by northern californ...       1
#
# [7613 rows x 2 columns]

# %%
target_test = grid_s_fit.predict(clear_data_test)

# %%
resulted_data = pd.DataFrame({'id': test['id'], 'target' : target_test})

# %%
resulted_data
# Out:
#          id  target
# 0         0       1
# 1         2       1
# 2         3       1
# 3         9       1
# 4        11       1
# ...     ...     ...
# 3258  10861       1
# 3259  10865       1
# 3260  10868       1
# 3261  10874       1
# 3262  10875       1
#
# [3263 rows x 2 columns]

# %%
resulted_data.to_csv('result.csv', index=False)
